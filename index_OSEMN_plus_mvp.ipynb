# %% [markdown]
# ## OVERVIEW OF OSEMiN

# %% [markdown]
# <img src='https://raw.githubusercontent.com/jirvingphd/fsds_100719_cohort_notes/master/images/OSEMN.png' width=800>
#
# <center><a href="https://www.kdnuggets.com/2018/02/data-science-command-line-book-exploring-data.html">
#     </a></center>
#
#
# > <font size=2em>The Data Science Process we'll be using during this section--OSEMiN (pronounced "OH-sum", rhymes with "possum").  This is the most straightforward of the Data Science Processes discussed so far.  **Note that during this process, just like the others, the stages often blur together.***  It is completely acceptable (and ***often a best practice!) to float back and forth** between stages as you learn new things about your problem, dataset, requirements, etc.
# It's quite common to get to the modeling step and realize that you need to scrub your data a bit more or engineer a different feature and jump back to the "Scrub" stage, or go all the way back to the "Obtain" stage when you realize your current data isn't sufficient to solve this problem.
# As with any of these frameworks, *OSEMiN is meant to be treated as guidelines, not law.
# </font>
#
#
# ### OSEMN DETAILS
#
# **OBTAIN**
#
# - This step involves understanding stakeholder requirements, gathering information on the problem, and finally sourcing data that we think will be necessary for solving this problem.
#
# **SCRUB**
#
# - During this stage, we'll focus on preprocessing our data.  Important steps such as identifying and removing null values, dealing with outliers, normalizing data, and feature engineering/feature selection are handled around this stage.  The line with this stage really blurs with the _Explore_ stage, as it is common to only realize that certain columns require cleaning or preprocessing as a result of the visualzations and explorations done during Step 3.
#
# - Note that although technically, categorical data should be one-hot encoded during this step, in practice, it's usually done after data exploration.  This is because it is much less time-consuming to visualize and explore a few columns containing categorical data than it is to explore many different dummy columns that have been one-hot encoded.
#
# **EXPLORE**
#
# - This step focuses on getting to know the dataset you're working with. As mentioned above, this step tends to blend with the _Scrub_ step mentioned above.  During this step, you'll create visualizations to really get a feel for your dataset.  You'll focus on things such as understanding the distribution of different columns, checking for multicollinearity, and other tasks liek that.  If your project is a classification task, you may check the balance of the different classes in your dataset.  If your problem is a regression task, you may check that the dataset meets the assumptions necessary for a regression task.
#
# - At the end of this step, you should have a dataset ready for modeling that you've thoroughly explored and are extremely familiar with.
#
# **MODEL**
#
# - This step, as with the last two frameworks, is also pretty self-explanatory. It consists of building and tuning models using all the tools you have in your data science toolbox.  In practice, this often means defining a threshold for success, selecting machine learning algorithms to test on the project, and tuning the ones that show promise to try and increase your results.  As with the other stages, it is both common and accepted to realize something, jump back to a previous stage like _Scrub_ or _Explore_, and make some changes to see how it affects the model.
#
# **iNTERPRET**
#
# - During this step, you'll interpret the results of your model(s), and communicate results to stakeholders.  As with the other frameworks, communication is incredibily important! During this stage, you may come to realize that further investigation is needed, or more data.  That's totally fine--figure out what's needed, go get it, and start the process over! If your results are satisfactory to all stakeholders involved, you may also go from this stage right into productionizing your model and automating processes necessary to support it.

# %% [markdown]
# ## PROCESS CHECKLIST

# %% [markdown]
# > Keep in mind that it is normal to jump between the OSEMN phases and some of them will blend together, like SCRUB and EXPLORE.

# %% [markdown]
# 1. **[OBTAIN](#OBTAIN)**
#     - Import data, inspect, check for datatypes to convert and null values
#     - Display header and info.
#     - Drop any unneeded columns, if known (`df.drop(['col1','col2'],axis=1,inplace=True`)
#     <br><br>
#
#
# 2. **[SCRUB](#SCRUB)**
#     - Recast data types, identify outliers, check for multicollinearity, normalize data**
#     - Check and cast data types
#         - [ ] Check for #'s that are store as objects (`df.info()`,`df.describe()`)
#             - when converting to #'s, look for odd values (like many 0's), or strings that can't be converted.
#             - Decide how to deal weird/null values (`df.unique()`, `df.isna().sum()`)
#             - `df.fillna(subset=['col_with_nulls'],'fill_value')`, `df.replace()`
#         - [ ] Check for categorical variables stored as integers.
#             - May be easier to tell when you make a scatter plotm or `pd.plotting.scatter_matrix()`
#
#     - [ ] Check for missing values  (df.isna().sum())
#         - Can drop rows or colums
#         - For missing numeric data with median or bin/convert to categorical
#         - For missing categorical data: make NaN own category OR replace with most common category
#     - [ ] Check for multicollinearity
#         - Use seaborn to make correlation matrix plot
#         - Good rule of thumb is anything over 0.75 corr is high, remove the variable that has the most correl with the largest # of variables
#     - [ ] Normalize data (may want to do after some exploring)
#         - Most popular is Z-scoring (but won't fix skew)
#         - Can log-transform to fix skewed data
#
#
# 3. **[EXPLORE](#EXPLORE)**
#     - [ ] Check distributions, outliers, etc**
#     - [ ] Check scales, ranges (df.describe())
#     - [ ] Check histograms to get an idea of distributions (df.hist()) and data transformations to perform.
#         - Can also do kernel density estimates
#     - [ ] Use scatter plots to check for linearity and possible categorical variables (`df.plot("x","y")`)
#         - categoricals will look like vertical lines
#     - [ ] Use `pd.plotting.scatter_matrix(df)` to visualize possible relationships
#     - [ ] Check for linearity.
#
#
# 4. **[MODEL](#MODEL)**
#
#     - **Fit an initial model:**
#         - Run an initial model and get results
#
#     - **Holdout validation / Train/test split**
#         - use sklearn `train_test_split`
#
#
# 5. **[iNTERPRET](#iNTERPRET)**
#     - **Assessing the model:**
#         - Assess parameters (slope,intercept)
#         - Check if the model explains the variation in the data (RMSE, F, R_square)
#         - *Are the coeffs, slopes, intercepts in appropriate units?*
#         - *Whats the impact of collinearity? Can we ignore?*
#         <br><br>
#     - **Revise the fitted model**
#         - Multicollinearity is big issue for lin regression and cannot fully remove it
#         - Use the predictive ability of model to test it (like R2 and RMSE)
#         - Check for missed non-linearity
#
#
# 6. **Interpret final model and draw >=3 conclusions and recommendations from dataset**

# %% [markdown]
# <div style="display:block;border-bottom:solid red 3px;padding:1.4em;color:red;font-size:30pt;display:inline-block;line-height:1.5em;">
# DELETE THIS CELL AND EVERYTHING ABOVE FROM YOUR FINAL NOTEBOOK
# </div>

# %% [markdown]
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time:
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:
# * Video of 5-min Non-Technical Presentation:

# %% [markdown]
# ## TABLE OF CONTENTS

# %% [markdown]
# *Click to jump to matching Markdown Header.*<br><br>
#
# - **[Introduction](#INTRODUCTION)<br>**
# - **[OBTAIN](#OBTAIN)**<br>
# - **[SCRUB](#SCRUB)**<br>
# - **[EXPLORE](#EXPLORE)**<br>
# - **[MODEL](#MODEL)**<br>
# - **[iNTERPRET](#iNTERPRET)**<br>
# - **[Conclusions/Recommendations](#CONCLUSIONS-&-RECOMMENDATIONS)<br>**
# ___

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# > Explain the point of your project and what question you are trying to answer with your modeling.
#
# ## Business Problem
#
# Summary of the business problem you are trying to solve, and the data questions that you plan to answer to solve them.
#
# ***
# Questions to consider:
# * What are the business's pain points related to this project?
# * How did you pick the data analysis question(s) that you did?
# * Why are these questions important from a business perspective?
# ***

# %% [markdown]
# # OBTAIN

# %%
import pandas as pd

df = pd.read_csv('data/tweet_data_apple_google.csv', encoding='latin-1')
df.head()
# Out:
#                                                                                                                                     tweet_text  \
# 0              .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                              @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                           @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4          @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
# 4                          Google
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 0                                   Negative emotion
# 1                                   Positive emotion
# 2                                   Positive emotion
# 3                                   Negative emotion
# 4                                   Positive emotion

# %% [markdown]
# The column names are unnecessarily long and difficult to read. We can rename the columns to make it easier for readability and interpretability.

# %%
df.columns = ['Tweet', 'Product/Brand', 'Emotion']
df.head()
# Out:
#                                                                                                                                          Tweet  \
# 0              .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                              @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                           @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4          @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#         Product/Brand           Emotion
# 0              iPhone  Negative emotion
# 1  iPad or iPhone App  Positive emotion
# 2                iPad  Positive emotion
# 3  iPad or iPhone App  Negative emotion
# 4              Google  Positive emotion

# %% [markdown]
# # SCRUB

# %% [markdown]
# ## Addressing Missing/Placeholder Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9093 entries, 0 to 9092
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tweet          9092 non-null   object
#  1   Product/Brand  3291 non-null   object
#  2   Emotion        9093 non-null   object
# dtypes: object(3)
# memory usage: 213.2+ KB

# %% [markdown]
# It seems like we are missing the body of text for 1 tweet and a total of 5,802 tags for which product/company the corresponding tweet was about. Let's start with looking at the missing tweet.

# %%
df[df['Tweet'].isna()]
# Out:
#   Tweet Product/Brand                             Emotion
# 6   NaN           NaN  No emotion toward brand or product

# %% [markdown]
# It seems like we are missing all the information from this row of data and without text data this row is of no use to us so we can go ahead and drop it.

# %%
df = df[df['Tweet'].isna() == False]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9092 entries, 0 to 9092
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tweet          9092 non-null   object
#  1   Product/Brand  3291 non-null   object
#  2   Emotion        9092 non-null   object
# dtypes: object(3)
# memory usage: 284.1+ KB

# %% [markdown]
# Now, let's take a closer look at the product/company column's missing values.

# %%
df[df['Product/Brand'].isna()].head()
# Out:
#                                                                                                                                            Tweet  \
# 5   @teachntech00 New iPad Apps For #SpeechTherapy And Communication Are Showcased At The #SXSW Conference http://ht.ly/49n4M #iear #edchat #asd
# 16                                                  Holler Gram for iPad on the iTunes App Store -  http://t.co/kfN3f5Q (via @marc_is_ken) #sxsw
# 32                                           Attn: All  #SXSW frineds, @mention Register for #GDGTLive  and see Cobra iRadar for Android. {link}
# 33                                                                                                 Anyone at  #sxsw want to sell their old iPad?
# 34                                                                 Anyone at  #SXSW who bought the new iPad want to sell their older iPad to me?
#
#    Product/Brand                             Emotion
# 5            NaN  No emotion toward brand or product
# 16           NaN  No emotion toward brand or product
# 32           NaN  No emotion toward brand or product
# 33           NaN  No emotion toward brand or product
# 34           NaN  No emotion toward brand or product

# %% [markdown]
# It looks like these tweets are not really directed towards a specific product or brand so we can go ahead and fill the null values with "Unknown" as a placeholder value for the time being.

# %%
df['Product/Brand'].fillna('Unknown', inplace=True)

# %%
df.isna().sum()
# Out:
# Tweet            0
# Product/Brand    0
# Emotion          0
# dtype: int64

# %% [markdown]
# ## Scrubbing Emotion Column

# %%
df['Emotion'].value_counts()
# Out:
# No emotion toward brand or product    5388
# Positive emotion                      2978
# Negative emotion                       570
# I can't tell                           156
# Name: Emotion, dtype: int64

# %% [markdown]
# Similar to the initial column names, the values in the emotion column can be cleaned up a bit for easy interpretability and to shorten the amount of typing for the code.

# %%
emotion_dict = {'Positive emotion': 'Positive', 'Negative emotion': 'Negative', 
                'No emotion toward brand or product': 'Neutral', "I can't tell": 'Unknown'}
df['Emotion'] = df['Emotion'].map(emotion_dict)
df.head()
# Out:
#                                                                                                                                          Tweet  \
# 0              .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1  @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                              @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                           @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4          @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
#
#         Product/Brand   Emotion
# 0              iPhone  Negative
# 1  iPad or iPhone App  Positive
# 2                iPad  Positive
# 3  iPad or iPhone App  Negative
# 4              Google  Positive

# %%
df['Emotion'].value_counts()
# Out:
# Neutral     5388
# Positive    2978
# Negative     570
# Unknown      156
# Name: Emotion, dtype: int64

# %% [markdown]
# Now we can take a look at the tweets with "Unknown" emotion values to see if we can notice any patterns or tell easily whether the tweet has a negative, neutral or positive emotion.

# %%
pd.set_option("display.max_colwidth", 300)
df[df['Emotion']=='Unknown']
# Out:
#                                                                                                                                                       Tweet  \
# 90                                     Thanks to @mention for publishing the news of @mention new medical Apps at the #sxswi conf. blog {link} #sxsw #sxswh
# 102                         ÛÏ@mention &quot;Apple has opened a pop-up store in Austin so the nerds in town for #SXSW can get their new iPads. {link} #wow
# 237                              Just what America needs. RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 341                                                                          The queue at the Apple Store in Austin is FOUR blocks long. Crazy stuff! #sxsw
# 368                                       Hope it's better than wave RT @mention Buzz is: Google's previewing a social networking platform at #SXSW: {link}
# ...                                                                                                                                                     ...
# 9020              It's funny watching a room full of people hold their iPad in the air to take a photo. Like a room full of tablets staring you down. #SXSW
# 9032                                                                                    @mention yeah, we have @mention , Google has nothing on us :) #SXSW
# 9037                                                                      @mention Yes, the Google presentation was not exactly what I was expecting. #sxsw
# 9058  &quot;Do you know what Apple is really good at? Making you feel bad about your Xmas present!&quot; - Seth Meyers on iPad2 #sxsw #doyoureallyneedthat?
# 9066                    How much you want to bet Apple is disproportionately stocking the #SXSW pop-up store with iPad 2? The influencer/hipsters thank you
#
#      Product/Brand  Emotion
# 90         Unknown  Unknown
# 102        Unknown  Unknown
# 237        Unknown  Unknown
# 341        Unknown  Unknown
# 368        Unknown  Unknown
# ...            ...      ...
# 9020       Unknown  Unknown
# 9032       Unknown  Unknown
# 9037       Unknown  Unknown
# 9058       Unknown  Unknown
# 9066         Apple  Unknown
#
# [156 rows x 3 columns]

# %% [markdown]
# Arguably, these tweets are difficult to classify without more context. Some of the tweets could be taken as sarcastic or genuine depending on the context.
#
# Since we need to have labels for our models, these tweets will not be useful in developing our model. Luckily they only make up approximately 1.7% of our data so we can go ahead and drop these rows.

# %%
df = df[df['Emotion']!='Unknown']
df['Emotion'].value_counts()
# Out:
# Neutral     5388
# Positive    2978
# Negative     570
# Name: Emotion, dtype: int64

# %% [markdown]
# ## Checking for and Addressing Duplicates

# %% [markdown]
# Now that we've addressed null values, and cleaned up our dataset a little bit more, next step is to check for duplicates to see if we have the same tweets represented multiple times.

# %%
len(df[df.duplicated()])
# Out:
# 22

# %% [markdown]
# It looks like we have 22 tweets that are duplicated in the dataset. Let's take a look at the duplicates for reference.

# %%
df[df.duplicated()]
# Out:
#                                                                                                                                                  Tweet  \
# 468                                                                                                     Before It Even Begins, Apple Wins #SXSW {link}
# 776                                                              Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 2232                                                Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #sxsw
# 2559                                                          Counting down the days to #sxsw plus strong Canadian dollar means stock up on Apple gear
# 3950  Really enjoying the changes in Gowalla 3.0 for Android! Looking forward to seeing what else they &amp; Foursquare have up their sleeves at #SXSW
# 3962        #SXSW is just starting, #CTIA is around the corner and #googleio is only a hop skip and a jump from there, good time to be an #android fan
# 4897                   Oh. My. God. The #SXSW app for iPad is pure, unadulterated awesome. It's easier to browse events on iPad than on the website!!!
# 5338                                          RT @mention ÷¼ GO BEYOND BORDERS! ÷_ {link} ã_ #edchat #musedchat #sxsw #sxswi #classical #newTwitter
# 5341                     RT @mention ÷¼ Happy Woman's Day! Make love, not fuss! ÷_ {link} ã_ #edchat #musedchat #sxsw #sxswi #classical #newTwitter
# 5881                                                 RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 5882                                                 RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #SXSW
# 5883                                                 RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 5884                                                 RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #SXSW
# 5885                                                 RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 6296                                    RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #sxsw
# 6297                                    RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #SXSW
# 6298                                    RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #sxsw
# 6299                                    RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #SXSW
# 6300                                    RT @mention Marissa Mayer: Google Will Connect the Digital &amp; Physical Worlds Through Mobile - {link} #sxsw
# 6546                                     RT @mention RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# 8483                  I just noticed DST is coming this weekend. How many iPhone users will be an hour late at SXSW come Sunday morning? #SXSW #iPhone
# 8747                                        Need to buy an iPad2 while I'm in Austin at #sxsw. Not sure if I'll need to Q up at an Austin Apple store?
#
#            Product/Brand   Emotion
# 468                Apple  Positive
# 776              Unknown   Neutral
# 2232             Unknown   Neutral
# 2559               Apple  Positive
# 3950         Android App  Positive
# 3962             Android  Positive
# 4897  iPad or iPhone App  Positive
# 5338             Unknown   Neutral
# 5341             Unknown   Neutral
# 5881             Unknown   Neutral
# 5882             Unknown   Neutral
# 5883             Unknown   Neutral
# 5884             Unknown   Neutral
# 5885             Unknown   Neutral
# 6296              Google  Positive
# 6297             Unknown   Neutral
# 6298              Google  Positive
# 6299             Unknown   Neutral
# 6300             Unknown   Neutral
# 6546             Unknown   Neutral
# 8483              iPhone  Negative
# 8747                iPad  Positive

# %%
df.drop_duplicates(keep='first', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8914 entries, 0 to 9092
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tweet          8914 non-null   object
#  1   Product/Brand  8914 non-null   object
#  2   Emotion        8914 non-null   object
# dtypes: object(3)
# memory usage: 278.6+ KB

# %% [markdown]
# Now that the duplicates have been addressed too we can perform an EDA on the data.

# %% [markdown]
# # EXPLORE

# %% [markdown]
# ## Tweets with Positive Sentiment

# %%
#parsing positive tweets into new df
df_positive = df[df['Emotion']=='Positive']
#verifying that neutral and negative tweets have been removed
df_positive['Emotion'].value_counts()
# Out:
# Positive    2970
# Name: Emotion, dtype: int64

# %%
#parsing tweets into a list
corpus_pos = df_positive['Tweet'].to_list()
corpus_pos[:5]
# Out:
# ["@jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW",
#  '@swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.',
#  "@sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)",
#  '#SXSW is just starting, #CTIA is around the corner and #googleio is only a hop skip and a jump from there, good time to be an #android fan',
#  'Beautifully smart and simple idea RT @madebymany @thenextweb wrote about our #hollergram iPad app for #sxsw! http://bit.ly/ieaVOB']

# %% [markdown]
# ### Tokenization

# %%
from nltk import TweetTokenizer
import string

def tokenize_tweets(corpus, preserve_case=False, strip_handles=True):
    tokenizer = TweetTokenizer(preserve_case=preserve_case, strip_handles=strip_handles)
    tokens = tokenizer.tokenize(','.join(corpus))
    return tokens

# %%
tokens_pos = tokenize_tweets(corpus_pos)

# %%
from nltk import FreqDist
freq = FreqDist(tokens_pos)
freq.most_common(10)
# Out:
# [(',', 4050),
#  ('#sxsw', 2983),
#  ('.', 2230),
#  ('the', 1590),
#  ('!', 1241),
#  ('link', 1214),
#  ('{', 1210),
#  ('}', 1210),
#  ('to', 1154),
#  ('at', 1019)]

# %% [markdown]
# We can see that our tokens contain a lot of punctuation and stop words like "to" and "at" since we haven't removed these yet. Prior to removing these though, we will be lemmatizing the tokens to make sure we're capturing any stop words that may be generated with this process.

# %% [markdown]
# ### Lemmatization

# %%
tokens_pos[:5]
# Out:
# ['know', 'about', '?', 'awesome', 'ipad']

# %%
from nltk.stem.wordnet import WordNetLemmatizer
# import nltk
# nltk.download('wordnet')

def lemmatize_tokens(tokens_list):
    lemmatizer = WordNetLemmatizer()
    tokens_lemm = [lemmatizer.lemmatize(word) for word in tokens_list]
    return tokens_lemm

# %%
tokens_pos_lemm = lemmatize_tokens(tokens_pos)

# %%
from nltk import FreqDist
freq = FreqDist(tokens_pos_lemm)
freq.most_common(10)
# Out:
# [(',', 4050),
#  ('#sxsw', 2983),
#  ('.', 2230),
#  ('the', 1590),
#  ('!', 1241),
#  ('link', 1218),
#  ('{', 1210),
#  ('}', 1210),
#  ('to', 1154),
#  ('at', 1019)]

# %% [markdown]
# Now that we lemmatized our tokens, since the stop words and punctuation arguably does not reveal anything about the sentiment of the tweets, we can go ahead and remove stop words and punctuation from them. This will allow us to see more relevant information.

# %% [markdown]
# ### Stop Word/Punctuation Removal

# %%
#getting stopwords from nltk
from nltk.corpus import stopwords
stop_lst = stopwords.words('english')

# %%
def remove_stop(tokens, stop_list=stop_lst, remove_punc = True):
    
    """This function takes removes stop words from a given tokens list. By default it also
    removes all punctuation."""
    
    #adding punctuation to stopwords
    if remove_punc == True:
        stop_list += list(string.punctuation)
        #adding additional characters to stopwords
        additional_punc = ['“','”','...',"''",'’','``','û', '\x9d']
        stop_list += additional_punc
    
    #removing stop words from tokens
    tokens_stopped = [word.encode('ascii','ignore').decode() for word in tokens if word not in stop_list]
    
    return tokens_stopped

# %%
tokens_pos_ls = remove_stop(tokens_pos_lemm)

# %%
from nltk import FreqDist
freq = FreqDist(tokens_pos_ls)
freq.most_common(50)
# Out:
# [('#sxsw', 2983),
#  ('link', 1218),
#  ('ipad', 1010),
#  ('rt', 931),
#  ('apple', 711),
#  ('google', 602),
#  ('2', 595),
#  ('store', 554),
#  ('iphone', 466),
#  ('app', 387),
#  ('new', 358),
#  ('', 328),
#  ('austin', 250),
#  ('get', 181),
#  ('#apple', 174),
#  ('launch', 173),
#  ('android', 161),
#  ('party', 151),
#  ('pop-up', 151),
#  ('sxsw', 144),
#  ('line', 143),
#  ('time', 136),
#  ('great', 135),
#  ('via', 132),
#  ('#ipad2', 129),
#  ('day', 124),
#  ('social', 122),
#  ('free', 120),
#  ('cool', 119),
#  ("i'm", 115),
#  ('like', 115),
#  ('map', 115),
#  ('one', 114),
#  ('win', 112),
#  ('today', 111),
#  ('ha', 108),
#  ('circle', 107),
#  ('w', 104),
#  ('go', 104),
#  ('come', 103),
#  ('wa', 100),
#  ('#sxswi', 96),
#  ('awesome', 93),
#  ('#ipad', 93),
#  ('love', 93),
#  ('good', 92),
#  ('network', 91),
#  ('mobile', 90),
#  ('temporary', 89),
#  ('downtown', 88)]

# %% [markdown]
# When we look at our updated most common 50 words list above, we can see that we still have some words that do not provide us with useful information about the sentiment of the tweets. Since we already know that the tweets are from the SXSW Conference, we can remove hashtags like '#sxsw' to our stop words list. Additionally, words like 'link' and 'rt' seem to be referring to external links and retweets respectively. However, 'link' could also have been used with its dictionary meaning. In order to understand how a word appears in our corpus we can build a function that can take a random sample of tweets out of the corpus, check whether the word we are looking for appears in any of the tweets and display the tweets that the word appears in.

# %%
stop_lst += ['#sxsw', '#sxswi', 'sxsw']

# %%
import numpy as np
def context_finder(word, corpus, n_samples=5, n_count=5):
    """This function takes n_samples with each sample having n_count tweets from the given corpus,
    and displays tweets that have the specified word in them. The goal of the function is to get 
    some context about a word."""
    
    i=0
    
    for _ in list(range(0,n_samples)):
        sample = np.random.choice(corpus, n_count)
        for tweet in sample:
            if word in tweet:
                print(tweet)
                i += 1
    print('-----------------------------------')
    print(f'Out of {n_count*n_samples} tweets analyzed, {i} tweets had the word "{word}" in them.')

# %%
context_finder('link', corpus_pos)
# Out:
# Not to fear, #SXSW attendees... you can pick up your iPad 2s from Apple's Austin pop-up shop! {link} via @mention
# RT @mention We're excited to be at #sxsw and giddy to announce that Music WithMe for Android is now available in Android Market. {link}
# Sitting on the ground waiting for my iPad at the Austin #apple popup store at #SXSW. What a geek I am.  {link}
# RT @mention Just got a shiny new #iPad2 at #SXSW ? Discover new music with {link} (built in HTML5, not Flash - looks great on iPad)
# Two guys from the google doodle team talk about the fun they have making the homepage pretty #sxsw {link}
# RT @mention Filming with the iPad is so much cooler than a lame iPhone... #sxsw (at @mention live show)  {link}
# Before It Even Begins, Apple Wins SXSW - TechCrunch {link} #sxsw
# ÛÏ@mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxswÛ @mention  bigger than gaga
# Security guard enjoying the iPad2 at the Apple Store in Austin... #sxsw #ipad2
#  {link}
# #iPad Lounge at @mention - Free daily for #sxsw - free coffee, #iPad #Art. Recharge. Refresh åÇ Austin Details {link}
# RT @mention The #iPad 2 Takes Over #SXSW [VIDEO]: {link} via Mashable
# #apple
# Any of my friends at SxSW willing to pick me up an iPad - will pay a premium. DM me #sxsw #atl {link}
# Enjoying a Google ice cream sandwich at the GSD&amp;M party...with an edible wrapper! #welivehere #gsdm #SXSW  {link}
# -----------------------------------
# Out of 25 tweets analyzed, 13 tweets had the word "link" in them.

# %% [markdown]
# No matter how many times we run the code above to get different samples, we see that the word 'link' is mainly used to refer to web links that were removed when the data was being parsed into the dataset. This doesn't provide us with any valuable insights into what the tweet may be about so we can go ahead and add the word to our stop words list.

# %%
stop_lst += ['link']

# %% [markdown]
# Now, we can take a look at 'RT' to confirm that it was used to refer to retweets.

# %%
context_finder('RT', corpus_pos)
# Out:
# Oooh. Want. RT @mention #Recap From recycled skateboards, these iPhone cases {link} #sxsw
# Me too. RT @mention Love it. #sxsw: &quot;apple comes up with cool technology no one's ever heard of because they don't go to conferences&quot;
# RT @mention This is one of the three best apps we've seen at #SXSW {link}
# RT @mention Even security guards in Austin enjoy iPad time. #SXSW (cc @mention {link}
# -----------------------------------
# Out of 25 tweets analyzed, 4 tweets had the word "RT" in them.

# %% [markdown]
# We can see that in all cases 'RT' or 'rt' since our tokenizer changed it to lower case was used to denote a retweet. Therefore, we can add it to our stop words list as well.

# %%
stop_lst += ['rt', '']

# %%
#updating the tokens list with updated stop words list
tokens_pos_ls = remove_stop(tokens_pos_ls, stop_list=stop_lst)

# %% [markdown]
# ### 50 Most Frequent Words in Positive Tweets

# %%
def find_frequent(tokens, n=50):
    freq = FreqDist(tokens)
    display(freq.most_common(n))

# %%
find_frequent(tokens_pos_ls)
# Out:
# [('ipad', 1010),
#  ('apple', 711),
#  ('google', 602),
#  ('2', 595),
#  ('store', 554),
#  ('iphone', 466),
#  ('app', 387),
#  ('new', 358),
#  ('austin', 250),
#  ('get', 181),
#  ('#apple', 174),
#  ('launch', 173),
#  ('android', 161),
#  ('party', 151),
#  ('pop-up', 151),
#  ('line', 143),
#  ('time', 136),
#  ('great', 135),
#  ('via', 132),
#  ('#ipad2', 129),
#  ('day', 124),
#  ('social', 122),
#  ('free', 120),
#  ('cool', 119),
#  ("i'm", 115),
#  ('like', 115),
#  ('map', 115),
#  ('one', 114),
#  ('win', 112),
#  ('today', 111),
#  ('ha', 108),
#  ('circle', 107),
#  ('w', 104),
#  ('go', 104),
#  ('come', 103),
#  ('wa', 100),
#  ('awesome', 93),
#  ('#ipad', 93),
#  ('love', 93),
#  ('good', 92),
#  ('network', 91),
#  ('mobile', 90),
#  ('temporary', 89),
#  ('downtown', 88),
#  ('opening', 88),
#  ('people', 82),
#  ('open', 82),
#  ('#iphone', 82),
#  ('got', 81),
#  ('apps', 78)]

# %% [markdown]
# ### WordCloud for Positive Tweets

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_wordcloud(tokens, collocations=False, background_color='black', colormap='Greens'):
    ## Initalize a WordCloud
    wordcloud = WordCloud(collocations=collocations, background_color=background_color, colormap=colormap)

    ## Generate wordcloud from tokens_stopped
    wordcloud.generate(','.join(tokens))

    ## Plot with matplotlib
    plt.figure(figsize = (12, 15), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis('off');

# %%
generate_wordcloud(tokens_pos_ls)

# %% [markdown]
# ### Bigrams for Positive Tweets

# %%
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()

# %%
#initializing finder
finder_pos = BigramCollocationFinder.from_words(tokens_pos_ls)

# %%
#getting frequency information from finder
bigrams = finder_pos.score_ngrams(bigram_measures.raw_freq)

# %%
bigrams[:50]
# Out:
# [(('ipad', '2'), 0.01693200215866163),
#  (('apple', 'store'), 0.006610901241230437),
#  (('iphone', 'app'), 0.0035752833243389097),
#  (('pop-up', 'store'), 0.003271721532649757),
#  (('social', 'network'), 0.002900701565029682),
#  (('google', 'map'), 0.0027995143011332975),
#  (('new', 'social'), 0.002597139773340529),
#  (('store', 'downtown'), 0.002361036157582299),
#  (('downtown', 'austin'), 0.0023273070696168377),
#  (('ipad', 'app'), 0.0023273070696168377),
#  (('temporary', 'store'), 0.002259848893685915),
#  (('apple', 'opening'), 0.002192390717754992),
#  (('google', 'launch'), 0.002192390717754992),
#  (('2', 'launch'), 0.001956287101996762),
#  (('called', 'circle'), 0.0019225580140313006),
#  (('network', 'called'), 0.0019225580140313006),
#  (('marissa', 'mayer'), 0.0018888289260658392),
#  (('launch', 'major'), 0.0018213707501349163),
#  (('major', 'new'), 0.0018213707501349163),
#  (('new', 'ipad'), 0.0018213707501349163),
#  (('store', 'austin'), 0.0016864543982730708),
#  (('google', 'party'), 0.0015178089584457636),
#  (('opening', 'temporary'), 0.001450350782514841),
#  (('apple', 'pop-up'), 0.0014166216945493795),
#  (('austin', 'ipad'), 0.0014166216945493795),
#  (('possibly', 'today'), 0.001382892606583918),
#  (('circle', 'possibly'), 0.0013491635186184566),
#  (('even', 'begin'), 0.0013491635186184566),
#  (('pop', 'store'), 0.0012817053426875337),
#  (('apple', 'come'), 0.0012142471667566108),
#  (('cool', 'technology'), 0.0011467889908256881),
#  (('ever', 'heard'), 0.0011467889908256881),
#  (("one's", 'ever'), 0.0011467889908256881),
#  (('app', 'store'), 0.0010793308148947653),
#  (('begin', 'apple'), 0.0010793308148947653),
#  (('go', 'conference'), 0.0010793308148947653),
#  (('popup', 'store'), 0.0010793308148947653),
#  (('technology', "one's"), 0.0010793308148947653),
#  (('come', 'cool'), 0.0010456017269293038),
#  (('heard', 'go'), 0.0010456017269293038),
#  (('line', 'apple'), 0.000978143550998381),
#  (('new', 'iphone'), 0.000978143550998381),
#  (('apple', 'open'), 0.0009444144630329196),
#  (('win', 'ipad'), 0.0009444144630329196),
#  (('#iphone', 'app'), 0.0009106853750674582),
#  (('apple', 'win'), 0.0009106853750674582),
#  (('love', 'apple'), 0.0009106853750674582),
#  (('google', 'circle'), 0.0008769562871019967),
#  (('rumor', 'apple'), 0.0008769562871019967),
#  (('store', 'ipad'), 0.0008769562871019967)]

# %% [markdown]
# ## Tweets with Negative Sentiment

# %%
#parsing positive tweets into new df
df_negative = df[df['Emotion']=='Negative']
#verifying that neutral and negative tweets have been removed
df_negative['Emotion'].value_counts()
# Out:
# Negative    569
# Name: Emotion, dtype: int64

# %%
#parsing tweets into a list
corpus_neg = df_negative['Tweet'].to_list()
corpus_neg[:5]
# Out:
# ['.@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.',
#  "@sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw",
#  'I just noticed DST is coming this weekend. How many iPhone users will be an hour late at SXSW come Sunday morning? #SXSW #iPhone',
#  '@mention  - False Alarm: Google Circles Not Coming Now\x89ÛÒand Probably Not Ever? - {link} #Google #Circles #Social #SXSW',
#  'Again? RT @mention Line at the Apple store is insane.. #sxsw']

# %% [markdown]
# ### Tokenization/Lemmatization/Stop Word Removal

# %%
#tokenize tweets
tokens_neg = tokenize_tweets(corpus_neg)
#lemmatize tweets
tokens_neg_lemm = lemmatize_tokens(tokens_neg)
#remove stop words & punctuation using the same stop words list
tokens_neg_ls = remove_stop(tokens_neg_lemm, stop_list = stop_lst)

# %% [markdown]
# ### 50 Most Frequent Words in Negative Tweets

# %%
find_frequent(tokens_neg_ls)
# Out:
# [('ipad', 179),
#  ('iphone', 145),
#  ('google', 136),
#  ('apple', 100),
#  ('2', 81),
#  ('app', 60),
#  ('', 55),
#  ('store', 47),
#  ('new', 43),
#  ('like', 43),
#  ('need', 35),
#  ('ha', 31),
#  ('circle', 29),
#  ('design', 29),
#  ('people', 29),
#  ('social', 28),
#  ('apps', 26),
#  ('get', 25),
#  ('wa', 24),
#  ('austin', 23),
#  ('think', 23),
#  ('time', 23),
#  ('launch', 22),
#  ('one', 22),
#  ('day', 21),
#  ('today', 21),
#  ('look', 21),
#  ('line', 20),
#  ('say', 20),
#  ('android', 19),
#  ('#ipad', 19),
#  ('would', 19),
#  ('network', 18),
#  ('phone', 18),
#  ('headache', 17),
#  ('news', 17),
#  ('go', 17),
#  ('long', 17),
#  ('product', 17),
#  ("i've", 16),
#  ("i'm", 16),
#  ('battery', 16),
#  ('user', 15),
#  ('thing', 15),
#  ('#apple', 15),
#  ('good', 15),
#  ('see', 15),
#  ('much', 15),
#  ('company', 15),
#  ('america', 15)]

# %% [markdown]
# ### Word Cloud for Negative Tweets

# %%
#generating word cloud for negative tweets
generate_wordcloud(tokens_neg_ls, colormap='Reds')

# %% [markdown]
# ### Bigrams for Negative Tweets

# %%
#initializing finder
finder_neg = BigramCollocationFinder.from_words(tokens_neg_ls)
#getting frequency information from finder
bigrams_neg = finder_neg.score_ngrams(bigram_measures.raw_freq)
#displaying top 50 bigrams
bigrams_neg[:50]
# Out:
# [(('ipad', '2'), 0.010442984672393464),
#  (('apple', 'store'), 0.004210880916287687),
#  (('iphone', 'app'), 0.0033687047330301497),
#  (('', ''), 0.0032002694963786426),
#  (('ipad', 'design'), 0.0032002694963786426),
#  (('design', 'headache'), 0.0028633990230756273),
#  (('new', 'social'), 0.00269496378642412),
#  (('social', 'network'), 0.0025265285497726125),
#  (('company', 'america'), 0.0021896580764695973),
#  (('fascist', 'company'), 0.00202122283981809),
#  (('google', 'circle'), 0.00202122283981809),
#  (('major', 'new'), 0.00202122283981809),
#  (('google', 'launch'), 0.0018527876031665825),
#  (('network', 'called'), 0.0018527876031665825),
#  (('called', 'circle'), 0.0016843523665150749),
#  (('launch', 'major'), 0.0016843523665150749),
#  (('fade', 'fast'), 0.0015159171298635675),
#  (('fast', 'among'), 0.0015159171298635675),
#  (('google', 'map'), 0.0015159171298635675),
#  (('iphone', 'battery'), 0.0015159171298635675),
#  (('news', 'apps'), 0.0015159171298635675),
#  (('#japan', 'relief'), 0.00134748189321206),
#  (('2', 'money'), 0.00134748189321206),
#  (('best', 'thing'), 0.00134748189321206),
#  (('classiest', 'fascist'), 0.00134748189321206),
#  (('gave', 'ipad'), 0.00134748189321206),
#  (("i've", 'heard'), 0.00134748189321206),
#  (('relief', 'need'), 0.00134748189321206),
#  (('thing', "i've"), 0.00134748189321206),
#  (('among', 'digital'), 0.0011790466565605525),
#  (('digital', 'delegate'), 0.0011790466565605525),
#  (('google', 'tv'), 0.0011790466565605525),
#  (('ipad', 'news'), 0.0011790466565605525),
#  (('kara', 'swisher'), 0.0011790466565605525),
#  (('money', '#japan'), 0.0011790466565605525),
#  (('need', 'ipad'), 0.0011790466565605525),
#  (('new', 'ipad'), 0.0011790466565605525),
#  (('possibly', 'today'), 0.0011790466565605525),
#  (('app', 'store'), 0.001010611419909045),
#  (('apple', 'classiest'), 0.001010611419909045),
#  (('apps', 'fade'), 0.001010611419909045),
#  (('circle', 'possibly'), 0.001010611419909045),
#  (('heard', 'weekend'), 0.001010611419909045),
#  (('ipad', '1'), 0.001010611419909045),
#  (('iphone', 'user'), 0.001010611419909045),
#  (('marissa', 'mayer'), 0.001010611419909045),
#  (('store', 'austin'), 0.001010611419909045),
#  (('weekend', 'gave'), 0.001010611419909045),
#  (('apple', 'elegant'), 0.0008421761832575374),
#  (('apple', 'like'), 0.0008421761832575374)]

# %% [markdown]
# ## Tweets Related to Apple

# %% [markdown]
# ### Feature Engineering Company Column

# %%
df['Product/Brand'].unique()
# Out:
# array(['iPhone', 'iPad or iPhone App', 'iPad', 'Google', 'Unknown',
#        'Android', 'Apple', 'Android App',
#        'Other Google product or service',
#        'Other Apple product or service'], dtype=object)

# %%
brand_dict={'iPhone': 'Apple', 'iPad or iPhone App': 'Apple', 'iPad': 'Apple', 
            'Google': 'Google', 'Unknown': 'Unknown',
            'Android': 'Google', 'Apple': 'Apple', 'Android App': 'Google',
            'Other Google product or service': 'Google',
            'Other Apple product or service': 'Apple'}
df['Brand'] = df['Product/Brand'].map(brand_dict)
df['Brand'].unique()
# Out:
# array(['Apple', 'Google', 'Unknown'], dtype=object)

# %%
df_apple = df[df['Brand']=='Apple']
corpus_apple = df_apple['Tweet'].to_list()

# %%
#tokenize tweets
tokens_apple = tokenize_tweets(corpus_apple)
#lemmatize tweets
tokens_apple_lemm = lemmatize_tokens(tokens_apple)
#remove stop words & punctuation using the same stop words list
tokens_apple_ls = remove_stop(tokens_apple_lemm, stop_list = stop_lst)

# %% [markdown]
# ### Word Cloud

# %%
#generating word cloud for negative tweets
generate_wordcloud(tokens_apple_ls, colormap='Blues', collocations=True)

# %% [markdown]
# ### Percentage of Positive, Neutral and Negative Sentiment

# %%
df_apple_sentiment = pd.DataFrame(df_apple['Emotion'].value_counts(normalize=True)).reset_index()
df_apple_sentiment.columns=['Emotion', 'Percentage']
display(df_apple_sentiment)
df_apple_sentiment.sort_values('Percentage', ascending=True, inplace=True)
# Out:
#     Emotion  Percentage
# 0  Positive    0.811431
# 1  Negative    0.161452
# 2   Neutral    0.027117

# %%
fig, ax = plt.subplots()
ax.barh(df_apple_sentiment['Emotion'], df_apple_sentiment['Percentage'], color=['Grey', 'Red', 'Green'])
ax.set_xlim(0, 1.1)
ax.set_xlabel('Percentage of Tweets')
ax.set_ylabel('Sentiment')
ax.set_title('Sentiment Percentages for Tweets about Apple')
# Out:
# Text(0.5, 1.0, 'Sentiment Percentages for Tweets about Apple')

# %% [markdown]
# ## Tweets Related to Google

# %%
df_google = df[df['Brand']=='Google']
corpus_google = df_google['Tweet'].to_list()

# %%
#tokenize tweets
tokens_google = tokenize_tweets(corpus_google)
#lemmatize tweets
tokens_google_lemm = lemmatize_tokens(tokens_google)
#remove stop words & punctuation using the same stop words list
tokens_google_ls = remove_stop(tokens_google_lemm, stop_list = stop_lst)

# %% [markdown]
# ### Word Cloud

# %%
#generating word cloud for negative tweets
generate_wordcloud(tokens_google_ls, colormap='Blues', collocations=True)

# %% [markdown]
# ### Percentage of Positive, Neutral and Negative Sentiment

# %%
df_google_sentiment = pd.DataFrame(df_google['Emotion'].value_counts(normalize=True)).reset_index()
df_google_sentiment.columns=['Emotion', 'Percentage']
display(df_google_sentiment)
df_google_sentiment.sort_values('Percentage', ascending=True, inplace=True)
# Out:
#     Emotion  Percentage
# 0  Positive    0.820776
# 1  Negative    0.149543
# 2   Neutral    0.029680

# %%
fig, ax = plt.subplots()
ax.barh(df_google_sentiment['Emotion'], df_google_sentiment['Percentage'], color=['Grey', 'Red', 'Green'])
ax.set_xlim(0, 1.1)
ax.set_xlabel('Percentage of Tweets')
ax.set_ylabel('Sentiment')
ax.set_title('Sentiment Percentages for Tweets about Google')
# Out:
# Text(0.5, 1.0, 'Sentiment Percentages for Tweets about Google')

# %% [markdown]
# # MODEL

# %% [markdown]
# ## Binary Classification

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### Parsing Data to New Dataframe

# %%
#removing neutral tweets for binary classification
df_binary = df[df['Emotion']!='Neutral']
#verifying that neutral tweets have been removed
df_binary['Emotion'].unique()
# Out:
# array(['Negative', 'Positive'], dtype=object)

# %%
#parsing tweets into a list
corpus = df_binary['Tweet'].to_list()
corpus[:5]
# Out:
# ['.@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.',
#  "@jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW",
#  '@swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.',
#  "@sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw",
#  "@sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)"]

# %%
df_binary['Tweet'].head(50)
# Out:
# 0                                 .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# 1                     @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# 2                                                                                 @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# 3                                                                              @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# 4                             @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
# 7                      #SXSW is just starting, #CTIA is around the corner and #googleio is only a hop skip and a jump from there, good time to be an #android fan
# 8                               Beautifully smart and simple idea RT @madebymany @thenextweb wrote about our #hollergram iPad app for #sxsw! http://bit.ly/ieaVOB
# 9                                                                        Counting down the days to #sxsw plus strong Canadian dollar means stock up on Apple gear
# 10                                         Excited to meet the @samsungmobileus at #sxsw so I can show them my Sprint Galaxy S still running Android 2.1.   #fail
# 11                              Find &amp; Start Impromptu Parties at #SXSW With @HurricaneParty http://bit.ly/gVLrIn I can't wait til the Android app comes out.
# 12                          Foursquare ups the game, just in time for #SXSW http://j.mp/grN7pK) - Still prefer @Gowalla by far, best looking Android app to date.
# 13                 Gotta love this #SXSW Google Calendar featuring top parties/ show cases to check out.  RT @hamsandwich via @ischafer =&gt;http://bit.ly/aXZwxB
# 14                                                                                              Great #sxsw ipad app from @madebymany: http://tinyurl.com/4nqv92l
# 15                                                                             haha, awesomely rad iPad app by @madebymany http://bit.ly/hTdFim #hollergram #sxsw
# 17                               I just noticed DST is coming this weekend. How many iPhone users will be an hour late at SXSW come Sunday morning? #SXSW #iPhone
# 18                                 Just added my #SXSW flights to @planely. Matching people on planes/airports. Also downloaded the @KLM iPhone app, nicely done.
# 19                                         Must have #SXSW app! RT @malbonster: Lovely review from Forbes for our SXSW iPad app Holler Gram - http://t.co/g4GZypV
# 20                                                     Need to buy an iPad2 while I'm in Austin at #sxsw. Not sure if I'll need to Q up at an Austin Apple store?
# 21                                Oh. My. God. The #SXSW app for iPad is pure, unadulterated awesome. It's easier to browse events on iPad than on the website!!!
# 22                                                                             Okay, this is really it: yay new @Foursquare for #Android app!!!!11 kthxbai. #sxsw
# 23                                                                 Photo: Just installed the #SXSW iPhone app, which is really nice! http://tumblr.com/x6t1pi6av7
# 24               Really enjoying the changes in Gowalla 3.0 for Android! Looking forward to seeing what else they &amp; Foursquare have up their sleeves at #SXSW
# 25    RT @LaurieShook: I'm looking forward to the #SMCDallas pre #SXSW party Wed., and hoping I'll win an #iPad resulting from my shameless promotion.  #ChevySMC
# 26                                                    RT haha, awesomely rad iPad app by @madebymany http://bit.ly/hTdFim #hollergram #sxsw (via @michaelpiliero)
# 27                                                                           someone started an #austin @PartnerHub group in google groups, pre-#sxsw. great idea
# 28                    The new #4sq3 looks like it is going to rock. Update for iPhone and Android should push tonight http://bit.ly/etsbZk #SXSW #KeepAustinWeird
# 29                                                                 They were right, the @gowalla 3 app on #android is sweeeeet! Nice job by the team there. #sxsw
# 30                                            Very smart from @madebymany #hollergram iPad app for #sxsw! http://t.co/A3xvWc6 (may leave my vuvuzela at home now)
# 31                         You must have this app for your iPad if you are going to #SXSW http://itunes.apple.com/us/app/holler-gram/id420666439?mt=8 #hollergram
# 36                  The best!  RT @mention Ha! First in line for #ipad2 at #sxsw &quot;pop-up&quot; Apple store was an event planner #eventprofs #pcma #engage365
# 38                                        @mention  - False Alarm: Google Circles Not Coming NowÛÒand Probably Not Ever? - {link} #Google #Circles #Social #SXSW
# 40               @mention  - Great weather to greet you for #sxsw! Still need a sweater at night..Apple putting up &quot;flash store&quot; downtown to sell iPad2
# 45                                                   #IPad2 's Û÷#SmartCoverÛª Opens to Instant Access - I should have waited to get one! - {link} #apple #SXSW
# 46                                                                    Hand-Held Û÷HoboÛª: Drafthouse launches Û÷Hobo With a ShotgunÛª iPhone app #SXSW {link}
# 47                                                                    HOORAY RT ÛÏ@mention Apple Is Opening A Pop-Up Store In Austin For #SXSW | @mention {link}
# 49                                                                                  wooooo!!! ÛÏ@mention Apple store downtown Austin open til Midnight. #sxswÛ
# 55                                          ÛÏ@mention @mention talking about {link} - Google's effort to allow users to have open systems #bettercloud #sxswÛ
# 57                                {link} RT @mention 1st stop on the #SXSW #Chaos &amp; @mention hunt: Austin Java. Get in the spy game 4 a chance 2 win an iPad!
# 62                                       #OMFG! RT @mention Heard about Apple's pop-up store in downtown Austin? Pics are already on Gowalla: {link} #sxsw #iPad2
# 64                                                                                                   Again? RT @mention Line at the Apple store is insane.. #sxsw
# 67                                                                                                          attending @mention iPad design headaches #sxsw {link}
# 68                                                                 Boooo! RT @mention Flipboard is developing an iPhone version, not Android, says @mention #sxsw
# 69                                             Check out @mention @mention &amp; @mention in line for their iPad 2 in Austin. Power to them! #sxswi #SXSW  {link}
# 72                                        Do it. RT @mention Come party w/ Google tonight at #sxsw! {link} - Bands, food, art, ice cream, nifty interactive maps!
# 75                                                                                  Holla! RT @mention At google party. Best ever! Get your butt over here. #sxsw
# 76                                                                             I love my @mention iPhone case from #Sxsw but I can't get my phone out of it #fail
# 80                                               New Post: @mention iPhone app makes it easy to connect on all social networks with people you meet  {link} #sxsw
# 81                                                                      Nice that @mention iPhone app is behaving today. Crashes yesterday were ridiculous. #sxsw
# 83                                    Nice!! RT @mention Hey, Apple fans! Get a peek at the space that's slated to be a pop-up #SXSW Apple Store tomorrow: {link}
# 84                            one thing @mention is doing so great is get a great, down to earth face to Google as a company - You can only love her #sxsw #sxwsi
# Name: Tweet, dtype: object

# %%
token_test = tokenize_tweets(['wow look at this http://bit.ly/ieaVOB'])

# %%
remove_stop(lemmatize_tokens(token_test))
# Out:
# ['wow', 'look', 'http://bit.ly/ieaVOB']

# %% [markdown]
# #### Tokenization

# %% [markdown]
# To tokenize our tweets we will be using the TweetTokenizer as it keeps mentions in the form of "@user" and hashtags in the form of "#tag" intact which may reveal additional information about the sentiments of the tweets.

# %%
from nltk import TweetTokenizer
import string

tokenizer = TweetTokenizer(preserve_case=False)
tokens = tokenizer.tokenize(','.join(corpus))

# %%
from nltk import FreqDist
freq = FreqDist(tokens)
freq.most_common(10)
# Out:
# [(',', 4840),
#  ('#sxsw', 3551),
#  ('.', 2775),
#  ('@mention', 2498),
#  ('the', 1899),
#  ('to', 1410),
#  ('!', 1332),
#  ('link', 1316),
#  ('{', 1312),
#  ('}', 1312)]

# %% [markdown]
# #### Lemmatization

# %% [markdown]
# #### Stop Word/Punctuation Removal

# %% [markdown]
# As expected, we have a lot of stop words and various punctuation in our corpus which will not reveal anything about the sentiment. So for the next step we can remove these to leave only content that truly matters for our analysis.

# %%
import nltk
# nltk.download('stopwords')
# nltk.download('punkt')


#getting stopwords from nltk
stop_lst = stopwords.words('english')
#adding punctuation to stopwords
stop_lst += list(string.punctuation)
#adding additional characters to stopwords
additional_punc = ['“','”','...',"''",'’','``']
stop_lst += additional_punc
#removing stop words from tokens
stopped_tokens = [word for word in tokens if word not in stop_lst]

# %%
freq_stopped = FreqDist(stopped_tokens)
freq_stopped.most_common(50)
# Out:
# [('#sxsw', 3551),
#  ('@mention', 2498),
#  ('link', 1316),
#  ('ipad', 1189),
#  ('rt', 1069),
#  ('apple', 810),
#  ('google', 738),
#  ('2', 650),
#  ('iphone', 611),
#  ('store', 588),
#  ('app', 447),
#  ('new', 401),
#  ('austin', 273),
#  ('\x89', 225),
#  ('#apple', 189),
#  ('get', 182),
#  ('launch', 181),
#  ('android', 180),
#  ('pop-up', 164),
#  ('sxsw', 158),
#  ('like', 153),
#  ('social', 150),
#  ('line', 147),
#  ('via', 146),
#  ('time', 145),
#  ('great', 143),
#  ('party', 138),
#  ('#ipad2', 137),
#  ('one', 133),
#  ('today', 132),
#  ("i'm", 131),
#  ('circles', 131),
#  ('day', 125),
#  ('cool', 124),
#  ('free', 122),
#  ('w', 116),
#  ('#ipad', 112),
#  ('maps', 112),
#  ('people', 111),
#  ('go', 109),
#  ('good', 107),
#  ('#sxswi', 106),
#  ('apps', 104),
#  ('network', 104),
#  ('love', 98),
#  ('mobile', 98),
#  ('awesome', 97),
#  ('#iphone', 94),
#  ('temporary', 94),
#  ('opening', 91)]

# %%
freq_stopped = FreqDist(stopped_tokens)
freq_stopped.most_common(50)
# Out:
# [('#sxsw', 3551),
#  ('@mention', 2498),
#  ('ipad', 1189),
#  ('apple', 810),
#  ('google', 738),
#  ('2', 650),
#  ('iphone', 611),
#  ('store', 588),
#  ('app', 447),
#  ('new', 401),
#  ('austin', 273),
#  ('\x89', 225),
#  ('#apple', 189),
#  ('get', 182),
#  ('launch', 181),
#  ('android', 180),
#  ('pop-up', 164),
#  ('sxsw', 158),
#  ('like', 153),
#  ('social', 150),
#  ('line', 147),
#  ('via', 146),
#  ('time', 145),
#  ('great', 143),
#  ('party', 138),
#  ('#ipad2', 137),
#  ('one', 133),
#  ('today', 132),
#  ("i'm", 131),
#  ('circles', 131),
#  ('day', 125),
#  ('cool', 124),
#  ('free', 122),
#  ('w', 116),
#  ('#ipad', 112),
#  ('maps', 112),
#  ('people', 111),
#  ('go', 109),
#  ('good', 107),
#  ('#sxswi', 106),
#  ('apps', 104),
#  ('network', 104),
#  ('love', 98),
#  ('mobile', 98),
#  ('awesome', 97),
#  ('#iphone', 94),
#  ('temporary', 94),
#  ('opening', 91),
#  ('downtown', 89),
#  ('got', 88)]

# %%
"i'm" in stop_lst
# Out:
# False

# %%
context_finder('w')
# Out:
# .@wesley83 I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# @jessedee Know about @fludapp ? Awesome iPad/iPhone app that you'll likely appreciate for its design. Also, they're giving free Ts at #SXSW
# @swonderlin Can not wait for #iPad 2 also. They should sale them down at #SXSW.
# @sxsw I hope this year's festival isn't as crashy as this year's iPhone app. #sxsw
# @sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)
# Beautifully smart and simple idea RT @madebymany @thenextweb wrote about our #hollergram iPad app for #sxsw! http://bit.ly/ieaVOB
# Counting down the days to #sxsw plus strong Canadian dollar means stock up on Apple gear
# Excited to meet the @samsungmobileus at #sxsw so I can show them my Sprint Galaxy S still running Android 2.1.   #fail
# Find &amp; Start Impromptu Parties at #SXSW With @HurricaneParty http://bit.ly/gVLrIn I can't wait til the Android app comes out.
# Foursquare ups the game, just in time for #SXSW http://j.mp/grN7pK) - Still prefer @Gowalla by far, best looking Android app to date.
# Gotta love this #SXSW Google Calendar featuring top parties/ show cases to check out.  RT @hamsandwich via @ischafer =&gt;http://bit.ly/aXZwxB
# Great #sxsw ipad app from @madebymany: http://tinyurl.com/4nqv92l
# haha, awesomely rad iPad app by @madebymany http://bit.ly/hTdFim #hollergram #sxsw
# I just noticed DST is coming this weekend. How many iPhone users will be an hour late at SXSW come Sunday morning? #SXSW #iPhone
# Just added my #SXSW flights to @planely. Matching people on planes/airports. Also downloaded the @KLM iPhone app, nicely done.
# Must have #SXSW app! RT @malbonster: Lovely review from Forbes for our SXSW iPad app Holler Gram - http://t.co/g4GZypV
# Need to buy an iPad2 while I'm in Austin at #sxsw. Not sure if I'll need to Q up at an Austin Apple store?
# Oh. My. God. The #SXSW app for iPad is pure, unadulterated awesome. It's easier to browse events on iPad than on the website!!!
# Okay, this is really it: yay new @Foursquare for #Android app!!!!11 kthxbai. #sxsw
# Photo: Just installed the #SXSW iPhone app, which is really nice! http://tumblr.com/x6t1pi6av7
# Really enjoying the changes in Gowalla 3.0 for Android! Looking forward to seeing what else they &amp; Foursquare have up their sleeves at #SXSW
# RT @LaurieShook: I'm looking forward to the #SMCDallas pre #SXSW party Wed., and hoping I'll win an #iPad resulting from my shameless promotion.  #ChevySMC
# RT haha, awesomely rad iPad app by @madebymany http://bit.ly/hTdFim #hollergram #sxsw (via @michaelpiliero)
# someone started an #austin @PartnerHub group in google groups, pre-#sxsw. great idea
# The new #4sq3 looks like it is going to rock. Update for iPhone and Android should push tonight http://bit.ly/etsbZk #SXSW #KeepAustinWeird
# They were right, the @gowalla 3 app on #android is sweeeeet! Nice job by the team there. #sxsw
# Very smart from @madebymany #hollergram iPad app for #sxsw! http://t.co/A3xvWc6 (may leave my vuvuzela at home now)
# The best!  RT @mention Ha! First in line for #ipad2 at #sxsw &quot;pop-up&quot; Apple store was an event planner #eventprofs #pcma #engage365
# @mention  - False Alarm: Google Circles Not Coming NowÛÒand Probably Not Ever? - {link} #Google #Circles #Social #SXSW
# @mention  - Great weather to greet you for #sxsw! Still need a sweater at night..Apple putting up &quot;flash store&quot; downtown to sell iPad2
# #IPad2 's Û÷#SmartCoverÛª Opens to Instant Access - I should have waited to get one! - {link} #apple #SXSW
# wooooo!!! ÛÏ@mention Apple store downtown Austin open til Midnight. #sxswÛ
# ÛÏ@mention @mention talking about {link} - Google's effort to allow users to have open systems #bettercloud #sxswÛ
# {link} RT @mention 1st stop on the #SXSW #Chaos &amp; @mention hunt: Austin Java. Get in the spy game 4 a chance 2 win an iPad!
# #OMFG! RT @mention Heard about Apple's pop-up store in downtown Austin? Pics are already on Gowalla: {link} #sxsw #iPad2
# Again? RT @mention Line at the Apple store is insane.. #sxsw
# attending @mention iPad design headaches #sxsw {link}
# Boooo! RT @mention Flipboard is developing an iPhone version, not Android, says @mention #sxsw
# Check out @mention @mention &amp; @mention in line for their iPad 2 in Austin. Power to them! #sxswi #SXSW  {link}
# Do it. RT @mention Come party w/ Google tonight at #sxsw! {link} - Bands, food, art, ice cream, nifty interactive maps!
# Holla! RT @mention At google party. Best ever! Get your butt over here. #sxsw
# I love my @mention iPhone case from #Sxsw but I can't get my phone out of it #fail
# New Post: @mention iPhone app makes it easy to connect on all social networks with people you meet  {link} #sxsw
# Nice that @mention iPhone app is behaving today. Crashes yesterday were ridiculous. #sxsw
# Nice!! RT @mention Hey, Apple fans! Get a peek at the space that's slated to be a pop-up #SXSW Apple Store tomorrow: {link}
# one thing @mention is doing so great is get a great, down to earth face to Google as a company - You can only love her #sxsw #sxwsi
# Thanks to @mention for her mention of our new #Speech iPad apps being showcased at the #SXSW Conf. {link} #sxswh #sxsh
# XMAS!! RT @mention Shiny new @mention @mention @mention apps, a new @garyvee book, pop-up iPad 2 stores... #SXSW is Christmas for nerds.
# Yai!!! RT @mention New #UberSocial for #iPhone now in the App Store includes UberGuide to #SXSW sponsored by (cont) {link}
# Fast, Fun &amp; Future: @mention of Google presenting at #sxsw on search, local and mobile
# Know that &quot;dataviz&quot; translates to &quot;satanic&quot; on an iPhone. I'm just sayin'. #sxsw
# .@mention &quot;Google launched checkins a month ago.&quot; Check ins are ok, but CHECK OUTS are the future. #sxsw #Bizzy
# ÛÏ@mention &quot;Google before you tweet&quot; is the new &quot;think before you speak.&quot; - Mark Belinsky, #911tweets panel at #SXSW.Û
# Kawasaki: &quot;Not C.S. Lewis level reasoning, but Apple's continued existence is evidence for the existence of God&quot; #bawling #sxsw
# Kawasaki: &quot;pagemaker saved Apple.&quot; Oh those were the days. #sxsw #jwtatl #enchantment  via @mention
# Spark for #android is up for a #teamandroid award at #SXSW read about it here: {link}
# #SXSW and #Apple iPad 2's are great, but thoughts are w/ Japan and APAC regions dealing w/ earthquake &amp; tsunami trauma. #sxswi
# Temporary #apple store is def not a tent, it's a powerhouse gym #SXSW  {link}
# Temporary #Apple store on 6th and Congress for #sxsw, along with 10,000 very happy hipsters.
# ÛÏ@mention #Apple wins #SXSW {link} Opening a temporary store in downtown Austin to support #iPad2 launch - That is good.
# #iPad and #Austin are trending today. Have fun at #sxsw all you nerdy nerds!!!
# Christian #iPad #iPhone devs I want to talk to u at #sxsw or after -maybe we can wk together on cool app! @mention me
# Stacks of #ipad2's waiting to be bought at #sxsw. I got mine, no hassle at all. Apple handled this perfectly {link}
# Does your #SmallBiz need reviews to play on Google Places...We got an App for that..{link}  #seo #sxsw
# Take that #SXSW ! RT @mention Major South Korean director gets $130,000 to make a movie entirely with his iPhone. {link}
# Beautiful #sxsw (@mention Apple Store, SXSW) [pic]: {link}
# Must have #SXSW app! RT @mention Lovely review from Forbes for our SXSW iPad app Holler Gram - {link}
# Temporary #sxsw apple store. Apple being sneaky as usual  {link}
# ÛÏ@mention #sxsw beta testing interactive book for iPad app by Moonbot studios out of Louisiana.  Cool app.Û
# Apple won #SxSW from day one. Seeing a TON of #iPad2
# ÛÏ@mention #sxsw ipad store sold out of everything except 64gig wifi only whiteÛ @mention Did you manage to get yours?
# ÛÏ@mention #sxsw ipad store sold out of everything except 64gig wifi only whiteÛ also known as the white jeans configuration.
# Offered a #sxsw ipad promo to ninjafinder users and fans who are not here at #sxsw. Sucks to not be here. #sxsw
# Just left #sxsw tradeshow demo of @mention at the Google Theatre. Ok, I get it. I see why all the presenters here are using it.
# Anyone at #sxsw want to make a quick hundred dollars? New #ipad2 from ad hoc apple store here gets hundred plus cost!
# Monday at #sxsw: barry diller, new york times, congress lunch, W Hotel party, Google party, six dirty martinis. How mondays should be.
# Seriously #sxsw? Did you do any testing on the mobile apps? Constant iPad crashes causing lost schedules, and no sync for WP7.
# ipad2 and #sxsw...a conflagration of doofusness.  {link}
# attention #sxsw'ers - {link} - rumored pop-up temporary Apple store for all your #sxsw iPad 2 launch needs.
# I went to #sxswi and all I won was this lousy #iPad #sxsw :-) :-) {link}
# This is a #WINNING picture #android #google #sxsw {link}
# You spent $1,000+ to come to SXSW.
#
# You've already used iPad 1.
#
# The wait is a couple city blocks.
#
# Why? #ipad2 #SXSW {link}
# It's like 10pm at night and there is a line around the block at the popup apple stores selling iPad2s. #sxsw
# I'm up to 2 iPad 2s seen in the wild. Both people say it is fast, but the still pics are terrible. #sxsw
# many iPad 2's snapping away at the keynote slides! #sxsw
# New Post: 3 iPhone Apps We'll Be Using at South By Southwest Interactive {link} #SXSW #SXSWi
# sweet new 3-d google maps demo going on in ballroom D #SXSW
# More than 35 million miles per day are driving with Google Maps Navigation! #SXSW
# #SXSW day 5 at the #apple store and there's still a line...and growing {link}
# If you're a band at #SXSW and want to share a track with your Audience from stage, use FrostWire for Android if there's Wi-Fi available
# if u have a iPhone you don't need a car'-use zimride etc to share rides #sxsw #shareable
# Picked up a Mophie battery case 4 my iPhone in prep for #SXSW. Not lugging around a laptop &amp; only using my phone was a huge win last year.
# Not to be a rumor monger, but this was a good read å_ #Google #Circles preview @mention #sxsw {link} by @mention via @mention #socbiz #fb
# Hobo with A Shotgun video game coming to iPad/iPhone users?! Yes please! {link} #SXSW
# build out a store in less than 24 hours and have one of the biggest launches in this company's history?  we got this.  #apple #sxsw #ipad2
# If iPhone alarms botch the timechange, how many #SXSW'ers freak? Late to flights, missed panels, behind on bloody marys...
# Shouts to all the ladies holding up their iPad 2's at free #sxsw shows to take photos while sipping free beer. /cc: @mention
# I meant I also wish I  at #SXSW #dyac stupid iPhone!
# picked up an ipad 2 at the #sxsw pop up  apple store! only 15 minute wait!
# Do I need any more for #sxsw! ipad, iphone, laptop, dictaphone, vid.camera.... Wow! Love to  meet the REAL 'cerebellum' charged people:)
# Found the app kyping my iPhone's geolocation &amp; not releasing when in background. Need a patch, @mention #batterykiller #SXSW
# the #SXSW app on the iPhone is live. RSVP for events from your phone &amp; check out sundayswagger.eventbrite.com 3/20 #scoremore
# Love this app! So awesome. RT @mention Must see #android app at #sxsw &quot;Bizzy&quot; {link}
# Love that Apple didn't let something like not having a retail store near #SXSW keep them away by opening a pop-up store {link}
# Surprise! Apple has opened a pop-up store in Austin so that the nerds in town for #SXSW can get their new ... {link} #Cnet
# Surprise! Apple has opened a pop-up store in Austin so that the nerds in town for #SXSW can get their new iPads. {link} #cnet
# Surprise! Apple has opened a pop-up store in Austin so that the nerds in town for #SXSW can get their new iPads.... {link}
# ÛÏ@mention Apple is a great example of a retail store layed out for the future - no 'registers' no 'checkout line'  #sxsw
# ÛÏ@mention Apple is opening up a temporary store in downtown Austin for #SXSW and the iPad 2 launch {link} #gswsxsw
# ÛÏ@mention Apple is opening up a temporary store in downtown Austin for #SXSW and the iPad 2 launch&quot; oh YAY more traffic.
# The #sxsw Apple Popup Store is open at noon, has a fresh shipment of iPad 2's, and I'm pretty sure I'm going to get one. [fingers crossed]
# #technews Apple saves SXSW, set to open pop-up store {link} #Tech_News #Apple #SXSW #tech
# ÛÏ@mention Apple store downtown Austin open til Midnight. #sxswÛ @mention there's still time :)
# &quot;The Apple store at the mall on Sunday is 10x as crowded as this. This line is fake. I just need a fucking dongle.&quot; Genius let me in. #sxsw
# Makeshift apple store at 6th and congress. You're kidding me. Amazing #sxsw #apple
# Temporary Apple Store being set up for #SXSW... shit now the temptation is going to be out of control.
# Temporary apple store opens at 5pm at 6th and congress. Line already growing. #iPad - view.io {link} via @mention #sxsw
# Temporary Apple Store will be a block from my office! Can't wait to see the line tomorrow. Photos to come... #sxsw #iPad2
# iPad news apps 'so last year' at #SXSW {link}
# Now there are 150 million mobile google maps users @mention #sxsw
# And a few are Android too RT @mention 10 New Mobile Apps IÛªll Be Using atåÊ#SXSW  {link}
# iPad apps are just like software development in that once you release it, you have to start working on the update. #sxsw
# Overheard at #sxsw &quot;the iPad is a relaxing computer&quot;: agreed. #iPad #apple
# Overheard at #sxsw interactive: &quot;Arg! I hate the iphone! I want my blackberry back&quot; #shocked
# ÛÏ@mention at #sxsw: &quot;apple comes up with cool technology no one's ever heard of because they don't go to conferences&quot;Û
# Last year at #SXSWi everbody was talking about the iPad, this year it's social media driven revolutions. This year is better. #sxsw
# ÛÏ@mention At Google, 4 people do the work of 7 people rather than 7 people doing the work of 4. #agileagency #SXSWÛ
# knackered at home playing with ipad and updating iphone. but timeline smashed with partytweets can't make me go to bed.. #sxsw
# overheard at MDW (and I'll second it) &quot;halfway through my iPhone battery already and I haven't even boarded the plane to #sxsw&quot; #amateurhour
# #technews At SXSW, Apple schools the marketing experts {link} #Tech_News #Apple #Jobs_Co #SXSW #tech
# First day at sxsw.  Fun final presentation on Google Doodles.  #GoogleDoodle #sxsw
# Huge line at the #apple store in #austin - #sxsw crowd tripping over each other to get the new ipad
# If ur not at the #google #aclu 80's party....u should be! #sxsw
# I laughed at the iPad until I spent this week hauling my macbook everywhere. Now I really want an iPad and a shoulder rub. #sxsw
# Any #SXSW attendees need a QR code reader for their iPhone? Tweet us an image of you with your badge and the first 5 get Optiscan free!
# Hey #SXSW attendees...you should hop in line at the #Apple store now. Only four days til your new iPad2 comes in...
# they took away the lego pit but replaced it with a recharging station ;) #sxsw and i might check prices for an iphone - crap samsung android
# .@mention Bad Apple: shows up late, Qs the process, poo-poos ideas, leaves early. Can even be &quot;I'm too creative&quot; or busy #gamestorming #sxsw
# Trying to balance the power of power needs on iPhone vs iPad at #sxsw. This 3G iPad sucks it out quick. Might have go airplane mode.
# My iPhone battery at 100%. #winning at #SXSW
# My iPhone battery can't keep up with my tweets! Thanks Apple.  #SXSW  #precommerce
# this will be fun to watch. #ipadmadness RT @mention Apple Opening Pop-Up Store In Austin For SXSW {link} #sxsw
# This will be out of control: #Apple set to open popup shop in core of #SXSW action {link} via @mention  cc @mention
# Celebrate Beauty of the Web @mention the MSFT #IE9 launch &amp; play our new #html5 game to win an iPad2 {link} #sxsw
# ÛÏ@mention Best thing I've heard this weekend at #SXSW &quot;I gave my iPad 2 money to #Japan relief. I don't need an iPad 2.&quot;  @mention
# IPad 2 is better..they have had time to improve #sxsw
# {link} Go beyond Earth Hour this year by sharing positive actions with the world. Download the #EarthHour 60+ iPhone app. #SXSW
# Google vs Bing on #bettersearch. Bing has a shot at success w/ structured search.  Potentially higher margin CPA model vs #Google. #SXSW
# impulsive buy = all your friends at #SXSW -&gt; I now have one too. Selling my 1st gen 32gb 3g iPad now
# ÛÏ@mention Buying 2 new iPad's with @mention #geekdate #apple #sxsw #ipad2Û :)
# Nice find by RSQ's @mention {link} #sxsw #iPad #app
# &quot;You can Google Canadian Tuxedo and lose yourself for hours&quot; #sxsw
# Exciting, canÛªt wait! RT @mention Apple is opening up a temporary store in downtown Austin for #SXSW &amp; the iPad 2 launch {link}
# Great for certain meetings. RT @mention Hello, Holler Gram, our new iPad app {link} #hollergram #sxsw
# Dont miss Charles Chen for Android/ChromeOS  Access at SXSW: @mention the Google booth in Exhibit Hall 3 @mention 1PM #sxsw
# If you're coming to #SXSW be sure to download the SXSW Go app, it has all the schedules and locations of the events. {link}
# Seriously considering leaving my MacBook Pro at home and flying solo with the iPad for a week. Think I can make it work? #sxsw
# Shipments daily - follow @mention #AppleATXdt 4 updates RT @mention Pop-up Apple Store seems to be out of pop-up iPad2s. #SXSW
# Four more days! #ipad #sxsw #weekend #battlela
# IPhone is dead. Find me on the secret batphone #sxsw.
# Google TV demo at the league for extraordinary hackers. Cool stuff! I like Web apps on TV. #google #sxsw #lxh
# Best iPad design: Big chunky elements. Generous space. Clarity trumps density. Tap quality trumps tap quantity. #tapworthy #sxsw
# Attending Designing iPad Interfaces - New Navigation Schemas w/ @mention Great stuff so far.  #sxsw
# Lovin the digital! @mention band sings into iPhone &amp; plays guitar app as fans record vids on iPad2s #CNN Digital #cnngrill #sxsw #sxswi
# We really DO need another big social network right now - thanks! #SXSW #Google {link}
# In Japan: Docomo introduced mobile apps six years before Apple came out with app store. #jpmobilesummit #sxsw
# Jeez guys dunno about an Apple pop-up over a Gold's Gym. Do u realize how un-Jobs-aesthetic that is? #SXSW #Apple
# Before it even begins, #Apple wins #SXSW {link} Opening a temporary store in downtown Austin to support #iPad2 launch #genius
# Before it even begins, Apple wins #SXSW {link}
# Before It Even Begins, Apple Wins SXSW - TechCrunch {link} #sxsw
# Before It Even Begins, Apple Wins SXSW {link} &lt;&lt; who will win big at #SXSW ?
# Before It Even Begins, Apple WinsåÊSXSW {link} #apple #sxsw
# Before It Even Begins, Apple Wins SXSW {link} #tc #apple #ipad2 #sxsw
# Before It Even Begins, Apple WinsåÊSXSW {link} via @mention #apple #sxsw
# Badgeless event! Free Drinks! ÛÏ@mention Heading to free Google-sponsored happy hour for Semantic Web Austin @mention Fogo de ChÌÁo #sxswÛ
# Timing is everything! iPad 2: Brand Winner at SXSW by @mention {link} #pnid #sxsw
# Hey #sxsw exhibitors, why not capture your booth experience with a Retrollect disc? Most popular disc wins iPad 2! {link}
# Photo: By far, the best #sxsw accessory is an ipad. Followed closely by a margarita. ;-) {link}
# I think I fell a bit more in love with #google today. Thanks for throwing the nerd party at the speakeasy during #SxSW
# The way I figure, an iPad 2 is a good replacement for not making it to #SXSW this year.
# I need to find a better #SXSW stream to follow. The inane iPad 2 tweets are surely not what SouthBy is about
# Do it! RT Find the hottest spots @mention w/ @mention Hot Spots #SXSW app on #WP7 {link} or iPhone {link}
# Google is focusing on bridging the digital/physical divide. Eg. maps, streetview, hotpot &amp; autonomous driving. #sxsw @mention
# #Apple To Follow Its Customers To #SXSW - Forbes - {link} - Alcoholics call this Û÷enabling.Ûª The rest of us call it genius.
# Good news for Austin-bound Apple fanboys: {link} #sxsw #ipad2
# Wish list for tech?  #NTN #SXSW Google Apps helps level the playing field for kids who may not have software at home
# Hitlantis for the iPad. Cool song explorer app. Hitlantis.com. #sxsw #musicviz
# Any of my friends at SxSW willing to pick me up an iPad - will pay a premium. DM me #sxsw #atl {link}
# Good talk from AKQAs @mention on iPad interface w/ callback to design principles. My wish: go beyond media/marketing examples. #fb #SxSW
# Person in front of me just took a picture with his new iPad #sxsw
# ÛÏ@mention Get ready for the word &quot;Circles&quot; to be trending #SXSWi #SXSW :)Û #Google #Circles #social
# After you get your food, don't forget to snap a photo to win a MacBook air, iPad 2, or Apple TV! #sxsw
# Austin is getting full, and #SXSW is underway.  I can tell because my iPhone is an intermittent brick. #crowded
# Google is giving free Google Labs laptops to open source coders who r attending this meet-up. #sxsw I got a cupcake:-)
# The #SXSW GO app no available for Blackberry and Windows 7 in addition to iPhone, iPad, and Android: {link}
# I want to go to the Apple pop-up store, but I'm afraid I'll leave with a new iPad. #SXSW
# OMG...I'm going down to #SXSW With: MacBook Pro, iPad, iPhone4, iPod, and a Galaxy Tab... #TechGeek
# I have my golden tickets f 4sq party Day after the real party #Redbullbpm with Felix da Housecat playing on iPad! #SXSW  {link}
# GSD&amp;M Google #sxsw party with @mention is blowing my mind. So much amazing food, drink, music, &amp; photo booth fun!
# .@mention Google Circles will be the first real alternative to Facebook #sxsw
# ÛÏ@mention Google now lets you block sites you can't stand {link} How about #sxsw blocking that looks like what I need
# Length of Google penalty based on severity of breach of webmaster guidelines. i.e.white text on white bgr might get 30 day pen. #sxsw #qagb
# ÛÏ@mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxswÛ
# It'll never beat myspace.
# ÛÏ@mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxswÛ @mention  bigger than gaga
# ÛÏ@mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxswÛ. Super interesting...
# ÛÏ@mention Google to Launch New Social Network Called Circles, Today? {link} #sxswÛ Applause for a new privacy model attempt
# Future of Google: Contextual discovery. Location + context helps us go deeper than ever. Searches without search @mention #sxsw
# iPad 2 in hand, awesome dude gave me cutsies on a 3 hour line. #austin #apple #sxsw #winning
# #smtravel hasn't heard - Google plans to launch a socnet in May - &quot;Circles&quot;. They have learned a lot in 5 years, lots has changed. via #sxsw
# I may not have invites to all the &quot;cool&quot; #sxsw #sxswi parties, but I do have two iPhone chargers in my pocket, so you'll be happy to see me!
# I've been having meetings while I'm in line at the #SXSW PopUp Apple Store for the iPad2. I love this place!
# #Apple to Hawk iPad 2 at #SXSW Festival Popup Store!  {link}  by @mention
# @mention  hello! Enjoy #Sxsw and ride anywhere in Austin for $10 . download the #GroundLink app, {link} booth 437
# Oh Lordy, here we go... RT @mention What time does the #apple store at #sxsw open? Pulling the #ipad2 trigger.
# Loved the honesty in Google's Marissa Mayer keynote: we have too many products and need to step up customer service for locations #sxsw
# Hey #SXSW how bout donating all this $ your spending on the new #iPad to Japan. Do you REALLY need that thing?
# Wondering how much revenue the Austin @mention store grossed on account of the ipad2, amid #sxsw ...what a strategic release...
# How could I forget my cell phone today for #SXSW what a fail glad I have my iPad #lifelinetotheworld
# .@mention I have a 3G iPhone. After 3 hrs tweeting at #RISE_Austin, it was dead!  I need to upgrade. Plugin stations at #SXSW.
# .@mention I have a feeling #SXSW will be the worst place to try &amp; get an iPad 2- everyone there will be trying to get one. #techiesunite
# Love that I have a MacBook, iPad, and iPhone with me at #sxsw this year. One runs out of juice, and I can jump to the next.
# Holy cow! I just got hooked by Paolo and Alex with a backup charger for my iPhone! facebook.com/powermat #powermatteam #sxsw #thanks
# Holy cow! I just got hooked by Paolo and Alex with a backup charger for my iPhone! facebook.com/powermat #powermattteam #sxsw #thanks
# I knew if I plied @mention with beer and stogies last night I'd weasel my way into the Team Android party tonight. #success #SXSW.
# I thought I would use my iPad a lot during #SXSW, but I haven't even touched it once.  Hmmzies.
# ÛÏ@mention I'll be at the Austin Convention Center today w/ my @mention fam... showing my new iPhone game. #SXSWÛ
# @mention  I'm beyond frustrated w/ @mention after this Samsung Moment runaround &amp; am leaving for ATT &amp; iPhone so I can enjoy #sxsw.
# I have no idea why this startupbus thing is so addictive: {link} #sxsw Also just added Android app.
# wondering if ppl in #sxsw on friday will queue at the convention centre or the apple store! xD i'm still figuring out wot i'll do!
# This Week in #iPad clip: @mention joins @mention to review the free #SXSW Go #App! {link} #iPad2 #SXSWGo
# If you're in a room full of people w/good Wi-Fi at #SXSW run #FrostWire on your Android {link} Share pics, apps, vids w/others
# If you're in a room full of people w/good Wi-Fi at #SXSW run #FrostWire on your Android {link} share pics, apps, vids w/others
# Hot spots in Austin on Gowalla right now: convention cnt, the Ignite party n the Apple store. #sxsw #sxswi
# I will be in Austin this weekend @mention #SXSW supporting Smarty Ears' launch of new iPad apps for Speech Therapy {link} #sxswh #sxsh
# For those in need of sweet Mac goodness at #SXSW, Apple has set up a temporary store downtown: {link}
# Zite, the Intelligent iPad Magazine: {link} &lt;  Deliciousness. #sxsw #trending #youneedthis
# google is interested in location based tech for indoor venues - businesses, convention centers etc.  Tech needs to improve first.  #sxsw
# Tim Soo's invisible instruments are jaw dropping. iPhone+Wii controller. {link} #lovemusicapi #sxsw
# Rockin an iPad 2 from the downtown Apple #SXSW store. #apple
# #technews iPad 2 Gets Temporary Apple Store for SXSW {link} #Tech_News #Apple #Apple_Store #iPad_2 #SXSW #tech
# AWESOME!! ipad 2 jailbreak!! {link} Grateful Dead #fab5 #sxsw
# New Post: iPad 2 Launches to Huge Lines at Apple Pop-Up Shop in Austin {link} #SXSW #SXSWi
# ÛÏ@mention iPad 2 Sold Out, 70% Went to New Buyers [REPORT] - {link} #sxsw #socialmedia #tech #ipad2 #mediaÛ
# Remaining iPad 2 stock at #sxsw Apple store.. Come get one :-)  {link}
# I won the iPad accessories bag! Thanks @mention #SXSW
# The #sxsw iPad app is pure gold. @mention
# the first iPad didn't even exist here last year and I already feel like I'm pulling out an antique everytime I use my iPad #sxsw #ipad2
# Turn your iPad into a 'physical messaging platform' with Holler Gram, a cheeky app we built for #SXSW. {link}
# shoot, my ipad will not display any search results :( will have to go through questions later #osmpw #sxsw
# Pic of my iPad-winning performance: {link} #sxsw #accordion #toodamnlucky
# I fear no iphone + #att 3gs slowpoke network during #sxsw &amp; #sxswmusic.
# The #SXSW iPhone app is one of the worst I've had to use in a very long time.
# Very cool iphone app just launched at #sxsw FlyPost: community bulletin board w/ location. Learn more: {link} {link}
# Pedicab + iPhone charger would be epic win. #SXSW
# &quot;the iPhone is a transient device used in short bursts; the iPad is an 'after 8pm, on the couch' device.&quot; @mention #sxsw
# Disliking iPhone twitter auto shortening links for me. #sxsw
# Flipboard is developing an iPhone version, not Android, says @mention #sxsw
# my iPhone is overheating. why are there so many british sounding people in texas? #SXSW
# So {link} is part of my presentation at #SXSW so good thing it's crashing now instead of then. Works best on iPhone/Android
# my sister is throwing the Google sxsw party tonigh Come!! {link} Bands, food, art, ice cream, nifty interactive #sxsw
# My iPhone is wilting under the stress of being at #sxsw.
# I believe it - I almost always use Google Maps on my iPhone RT @mention 40% of Google Maps use is Mobile says @mention #sxsw
# Of course it does! RT @mention #SXSW Gets Its Own Apple Store {link} #geeksrule
# Gotta get it! RT @mention Hey Taariq, howdy from Texas, fav #sXsw app is: {link} &lt;--android-or get Iphone #UsGuys
# I'm a bit jealous seeing #SXSW attendees with #ipad2. My iPad seems so obsolete...
# &quot;I'm just learning all of these things from the screen.&quot; A 4-year old's explanation of how she instantly knew how to use an iPad. #sxsw
# This iPad keeps me awake. Thank god I bought it.... #SXSW
# iPhone, I know this #SXSW week will be tough on your already-dwindling battery, but so help me Jeebus if you keep correcting my curse words.
# Google to launch a social network, Circles, at #SxSW - {link} - Who's excited?
# Google to Launch Major New Social Network Called Circles  {link} #sxsw (via @mention
# Google to Launch Major New Social Network Called Circles (Updated) {link} *Not launched at #SXSW, but soon. Should I care?
# Google to Launch Major New Social Network Called Circles, {link} #sxsw - Brazil's orkut users have been waiting.
# Google to Launch Major New Social Network Called Circles, Possibly Today (Updated) by @mention {link} #sxsw
# Google to Launch Major New Social Network Called Circles, Possibly Today {link}
# Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw - this will surely be a threat to FB
# Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw #Pakistan #cwc2011
# Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw rt @mention via @mention
# Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxswÛ &gt;&gt; Should be good
# Google to Launch Major New Social Network Called Circles, Possibly Today @mention #sxsw #sxswi - {link} via @mention
# Google to Launch Major New Social Network Called Circles, Possibly Today by @mention {link} via @mention #SXSW #ScreenFuture
# Google to Launch Major New Social Network Called Circles, Possibly Today by @mention {link} via @mention #sxsw #sxswi
# Google to launch Major New Social Network called Circles: {link} Possibly today #SXSW
# Google to Launch Major New Social Network Called Circles!!!  #google #circles #sxsw {link}
# Google to Launch Major New Social Network Called Circles!!! #google #circles #sxsw {link}
# Google to Launch Major New Social Network Called Circles.. {link} #sxsw v @mention @mention
# Google to launch new social network at SXSW? - CNET News {link} #sxsw
# Google to launch new social network Circles, linking u more closely to peeps u connect w/most. possibly today @mention #sxsw!
# Google to launch product! Wait, no launch, but product exists.  Wait, product does not exist! #sxsw {link}
# God, it's like being at #sxsw - have iMac, MacBook, iPhone and BlackBerry all staring at me. Enough! Time to read a book - remember those?
# ha, seems like it --&gt; ÛÏ@mention The only news at SXSWi was Apple's temporary iPad store? #sxsw #wth?Û
# Saw giant line, thought it was for movie premiere. It was at apple store for iPad 2. Heard more screams than at premiere! #SXSW
# Since I'm listening to Google's Marissa Mayer, but engaging on Twitter I'm wondering what the heck happened to Google Buzz. #SXSW
# I've been looking forward to the google/bing q/a on website ranking all week. #sxsw
# There are lots of other Google efforts helping Japan! and many other global issues. :)  RT @mention RT @mention wtf is up w/people at #sxsw
# So geeky! Love it! RT @mention Apple is opening up a temporary store in downtown Austin for #SXSW and the iPad 2 launch {link}
# .@mention Love it. @mention @mention #sxsw: &quot;apple comes up w/ cool technology no one's ever heard of because they don't go 2 conferences&quot; me 2!
# ÛÏ@mention Love it. @mention at #sxsw: &quot;apple comes up with cool technology no one's ever heard of because they don't go to conferences&quot;Û
# trying to make a detailed, colour coded, google calendar for #SXSW is proving to be really tough. also, when did i get this organized?!
# &quot;How many people have iPads?&quot; Whole room raises hand. &quot;iPad 2's?&quot; Half the room raises hand. #stillonamacbook #shame #sxsw #nfusion
# I think I may go iPad only -- no laptop -- today at #SXSWi.  Any #SXSW veterans have any reasons why I shouldn't?
# They made me a #soundcloud ambassador for #sxsw I upload music from shows &amp; they reward me RT @mention This soundcloud android app is fresh
# Alert the media.  I just saw the one and only Android tablet at #sxsw.  Like finding a needle in a haystack!  I also saw a Cr-48.
# But great mental image. RT @mention People in this session are taking photos w/ their iPad 2s up in the air... #doingitwrong #sxsw
# I think I might go all weekend without seeing the same iPad case twice... #sxsw
# For sure! Mine does via iPad RT @mention You know you are an #agnerd if your #dairy relies on evernote!  {link} #SXSW #agchat
# Bummed to miss #SXSW this year, but we're all quarantined with the same kiddie cold, and I have GarageBand on my iPad to comfort me. #fb
# How did I miss this?! I knew I spotted NFC enabled google places marker at birds! No wonder all the billboard near #sxsw {link}
# Loving my Morphie JuicePack today for a recharge of iPhone. So worth it. #sxsw
# Brilliant move by Apple: before it even begins, Apple wins #SXSW {link}
# How could Murphy USA better serve you inside Google Maps on your phone? -Google is announcing great features in v5 #SXSW
# Why can't my #iPad and I be intimate together? #tapworthy #designflaws #sxswi #sxsw
# compiling my #sxsw list in one google doc is taking a lot longer than i thought... so many parties. so many good musicians.
# Day 1 and my charger kicked the bucket. Where the heck is the Apple store that's within walking distance? #sxsw
# With just my iPhone and iPad on me, I feel very unequipped compared to everyone else. Dang! #sxsw
# Hm? Do we need another 1? RT @mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# ÛÏ@mention New #UberSocial for #iPhone now in the App Store includes UberGuide to #SXSW sponsored by #Mashable {link}
# Couple of new blogs: random tips on awesome iPhone app dev: {link} and the politics behind HTML5: {link} #SXSW
# This dude next to me is holding and using an iPad 2 like it's a trophy. #sxsw #lookingforwardtothemusicfest
# There are no hard feelings towards Google. @mention says they would make a great partner. #checkins #sxsw #pnid
# ÛÏ@mention Not a rumor: Apple doing popup store in downtown Austin for #SXSW &amp; iPad 2 launch {link} Smart move, 1of many #dfcbto
# Google is not launching anything during #sxsw, just partying {link} #circles
# Farooqui: Now about mobile. iOS, with Android catching up fast and will grow more once they allow in-app purchasing. #gamesfortv #sxsw
# Fear not! Now extended through Wed! --&gt; RT @mention RT @mention Last day for Apple popup is Sunday 3/13 #SXSW #AppleATXdt
# &quot;All of #SXSW is nothing but a teeming sea of iPhone addicts too busy Twittering to ever engage with one anothÛ_ (cont) {link}
# Not a fan of a new #sxsw trend - audience sharing opinions via holding up an iPad. Not here to listen to you. #annoying
# The power of Apple: People who have spent hundreds of dollars to attend #SXSW are spending the day waiting in line for an iPad.
# Continuum of attitudes on crowdsourcing: Gap is to &quot;I hear you&quot; as Apple is to &quot;I'll tell you&quot; #sxsw
# Third era of google logos = an interactive play space. Get ready. #GoogleDoodle #sxsw #gsdm
# Highlight of my day was undoubtedly meeting @mention from Google for 30 seconds after her softball fancrazed preso at #SXSW
# Wow, lots of the #SXSW audience haven't seen the 3D vector panning in Google Maps for Mobile - gasps of appreciation
# Tomlinson of TX Observer says Apple subscription data holding is biggest impediment to success. #newsapps #sxsw
# #technews OMG/JK: A Kiss For iPad 2, A Slap For Xoom {link} #Tech_News #iPad_2 #JK #OMG #SXSW #tech
# It's also on Android. :) RT @mention Foodspotting's hit iPhone app finds the foods you crave {link}  #cnnmoneysxsw #sxsw
# USA Today on iPad: makes good use of digital shortcuts while still looking like a newspaper. @mention #tapworthy #sxsw
# iPhone in one hand, caramel macchiato in the other. Ouch-hiss-hot!  With apparently two pumps of lava. And so it begins... #sxsw #tmsxsw
# I can haz one? ÛÏ@mention Just showed off @mention Charge Anywhere at a bar to charge my iPhone and the whole table wanted to buy one. #SXSWÛ
# #Apple to open a &quot;pop-up&quot; store across the street from #SXSW for two weeks? Umm, genius. If it isn't obvious... *cough (#iPad2) cough*
# #Apple to Open Pop-Up Shop at SXSW {link} &lt;---cool concept but I wouldn't spend my #SXSW waiting for the #iPad2
# Apple has opened a makeshift store for #sxsw, iPad2 will be available at 5pm today... #tempted
# Hey #SXSW our new iPad app Dexteria is now available {link} like us on Facebook {link}
# IPad 2 is out! Plenty of people at the store..and in line..scarfing them up. #SXSW (@mention Apple Store, SXSW w/ 65 others) {link}
# Nice line outside #sxsw #apple store! I guess people want some iPad2s!!!
# @mention  packing a point by showing iphone fragmentation  #SXSW
# At google party. Best ever! Get your butt over here. #sxsw
# Hey #sxsw peeps! Our new IPhone app ON #Voicefeed just launched the US: {link} Check it out and let us know what you think!
# Google is planning to launch a major new Social Network called Circles. Previews so far have been super positive #SXSW {link}
# I left my pocket guide at the hotel. I don't know how I'm going to cope. What does that say about the usability of iPad/iPhone app? #SXSW
# The apple pop up store at #sxsw is no joke.
# The Apple pop-up store is more attractive and impressive than many permanent retail stores. #sxsw
# The Apple pop-up store line finally dwindled. Time to check out iPad2. #sxsw
# The apple popup store was off the hook last night at #sxsw - singing, dancing, high fives on new iPad purchase
# Brilliant PR stunt, business idea and customer service response in one: Apple sets up a pop-up store at #sxsw, draws crowds, media &amp; revenue
# Excellent presentation by @mention on &quot;The untapped iPad Market, is your site POUR?&quot; #sxsw #poursite #accessibility
# iPad 2 is pretty sick! Almost makes me think I need one! #sxsw
# .@mention Problem with Google Living Stories was the process of creating content didn't change - was just an interface. #hacknews #SXSW
# BRILLIANT READ: Attention Marketers and Media Professionals: the iPad won't save you by @mention  {link} #usguys #SxSW
# Google is reproducing digitally the way you organically consume information. Goggles is the best example of that. #SXSW #MarissaMeyer
# .@mention reveals average time users spent on NYT's Oscars iPad app was 16mins: &quot;That blew my mind&quot; #newsapps #sxsw
# They were right, the @mention 3 app on #android is sweeeeet! Nice job by the team there. #sxsw
# Congrats! RT @mention Good News! Austin Eats: BBQ for iPhone is now available - {link} #iTunes #Austin #BBQ #SXSW #SXSWi
# Congrats! RT @mention Just won an awesome iPad from @mention at the #sxswbuffalo lounge! My #sxsw experience is complete! #QuiBidsWin
# Congrats! RT @mention Yes! Gowalla wins best Andoid app at the Team Android Choice Awards. Thanks all! #sxsw
# I like it RT @mention @mention &quot;Google before you tweet&quot; is the new &quot;think before you speak.&quot; - Mark Belinsky #911tweets panel #SXSW.
# L.A.M.E.  RT @mention &quot;...by the law of averages, better than Buzz&quot; RT @mention &quot;Google Circles will be ______ &quot;  #sxsw
# Love it . RT @mention From #Apple to Naomi Campbell: pop-up stores are all the rage: {link} #sxsw
# New #SXSW rule: no more ooing and ahing over your new iPad. We get it. Its not a big deal. Everybody has one now... :-)
# #sxsw hot rumor about Google's new social network &quot;Google Circles&quot; {link} (photo, video, status sharing)
# google is saving users 2 years of time with gps navigation using alternate routes w traffic #sxsw
# Wow. Just saw someone using a computing device other than a Mac or an iPad here at #sxsw A rare sighting indeed.
# My iPhone says it can't connect to the Internet even though #sxsw wifi works great on my computer. Any suggestions?
# Ok,I have seen two impressive lines since I'm at #SXSW  the one at the Apple Store yesterday. &amp; the @mention party now cc @mention
# #Apple is setting up a pop-up store in downtown Austin (to sell bajillions of iPad2s to #sxsw attendees, of course!) {link}
# #ipad art show at @mention just in time for #sxsw check it out you interactive fools
# ÛÏ@mention So @mention just spilled the beans: next platform for Flipboard is the iPhone. Team started working on it. #sxflip #SXSW #SXSWiÛ Gr8!
# @mention  so #jealous of you. #sxsw &amp; you have the new iPad?!
# Impressed so far with the iPad 2's slim form and &quot;instant on&quot;-ness that I've seen. Haven't tried one myself yet. #sxsw #sxswi
# There are so many ppl w/ Apple products at #SXSW - I think my head is about to explode! (this message brought to you via iPhone)
# #apple is so smart to open a Pop-Up store in #Austin while #sxsw crowd's there.
# Q: Why do social sites like Delicious often have better results than Google or Bing? #qagb #sxsw
# iPad 2 is sold-out and 70% were 1st time users #sxsw
# We've got some exciting things that we'll be showing off at #SXSW this year: including drag and drop store management on your iPhone
# Talked to some great developers at the Android meetup. Looking forward to working with them. #sxsw #android #androidsxsw
# so we had some information from @mention this morning that an apple store is getting build at #sxsw for two weeks.  ipad2 love? - jealous!
# I've seen some of the best iPad cases ever here at #sxsw - I'm starting to transfer a bit of my book fetishism to iPads slowly but surely.
# ÛÏ@mention Spotted at #SXSW: Man in need of an iPad (2?) ÛÒ {link} #sxswiÛ man in need should go to SXSW apple store
# There are still iPad 2s to be had, at least at the #sxsw pop-up Apple store. @mention just bought one.
# The Apple store in austin and 100 people taking a pic of it. #ipad2 #sxsw {link}
# Oh, Apple Store...you look so at home here in downtown Austin #SXSW #sxtxstate @mention Apple Store, SXSW {link} #photo
# Great new support for web fonts @mention here at #SXSW #google
# {link} At SXSW, Apple schools the marketing experts #sxsw
# Just read that #apple will be at #SXSW selling iPad 2 on release day. Good lord, the vortex of smugness that day may be unbearable.
# Is it bad that I just want to go home and read my Google Reader feed? #geek #sxsw
# Check out the #dokobots game from @mention for iPhone and Android.  Seems pretty cool. #geogames #SXSW #tmsxsw
# ÛÏ@mention The 10 most dangerous IPhone apps. #sxsw {link}
# Hopefully the best thing that comes from #SXSW isn't the fact people flew to Austin to pick up an iPad.
# First day the exhibit hall is open at #SXSW! Stop by the #EMC booth to enter to win an iPad 2! @mention @mention
# Following the Google/Bing QA session at #SXSW.  Great insights for webmasters #qagb
# It's like the Ipoo app for iphone!  @mention Ha! RT @mention 4chan is the Internet's bathroom wall. #sxswmoot #SXSW
# PdaNet is the most awesome app yet for the android! #sxsw @mention likes!
# Check out the new @mention app {link} - this is gonna be HUGE next week at #sxsw and beyond.
# ÛÏ@mention The new Whrrl app is now live in the iPhone app store AND Android marketplace. Get it while it's hot! (Just in time for #SXSW!)Û
# Just used the ol' iPad to help some Brits find their hotel in Austin. #gooddeed #sxsw #winning
# I must be the only one at #sxsw without an iPad2. Someone needs to make a case that makes my original iPad look like a new 2nd gen.
# iPad 2 is the star gadget of SXSW: {link} #sxsw
# So I went the whole day w/out my laptop &amp; just used my iPad 1. Things I missed: FTP, cloudapp, fast typing, &amp; skype. #iPad #sxsw
# Exploring the World in 3D with XML combines Google Earth w/ location of individuals to show where you've been over time. So cool! #SxSW
# Last year there was not a single iPad in public at #sxsw. Today, they're more common than laptops, and I haven't seen any android tablets.
# You think there would be a #sxsw app for blackberry. Just when I gave iPhone the finger! Guess I'll have to carry around an ipad. LAME
# Wow, this thing is insanely thin &amp; light. Hold out for the iPad 2. Seriously. #sxsw #mosaicxm  {link}
# Among the things I am missing at #sxsw: the Google-ACLU 80's dance party.
# I like to think Apple decided to sell their new iPad at #SXSW based on my suggestion - {link} Everyone... you are welcome.
# If anyone thinks I'm going to be walking around at #sxsw with an old and inferior iPad 1 once the iPad 2 is released, well, they are wrong!
# People in this Apple store do not...smell great. #sxsw #hereforwork #nottheipad2
# Check out this new #android app #bizzy, we're using it to check out #sxsw {link}
# Check out this video to get a glimpse at what the action was like -The iPad 2...#ipad #sxsw #gadgets {link} Could not resist.
# I believe this, too. They're good. RT @mention My life would be so much better with an iPad. #brainwashed #lines #SXSW
# There are thousands of iPad 2's floating around Austin at #sxsw and I have not seen even one single Android tablet.  Not even one. Zero.
# Excellent tip from @mention Going to #SXSW? The new iPhone guide to #Austin by @mention is free March 9-15. Hard to beat free. #lp
# Thank you to @mention for letting me test drive a car to the Apple store. Now lets hope that they can fix my phone!! #sxsw
# On my way to &quot;iPad Design Headaches.&quot; Not sure it's bloggable, but I'm sure it will be interesting! #SXSW {link}
# On my way to #sxsw. But I forgot my iPad! %^*%#!! (@mention Cleveland Hopkins Airport w/ 2 others) {link}
# Listening to google q&amp;a. With what she is saying I see yelp and other services going to die... #sxsw so far interesting
# Listening to google's Marissa Mayer discuss new products including google hotpot - watch out yelp!  #SXSW
# Expecting to see a flood of shiny new ipad2's today @mention Line at apple store was around the block #sxsw
# So we get to see google fail at social on another day RT @mention Okay, no Google Circles debuting at #sxsw today
# Listening to TWiT live @mention #sxsw. Also went to boxee keg party, google robots event, saw tim ferris speak, checked out ebay hackathon!
# I'm going to wait for the #iPad 4. you KNOW its going to be better than the iPad 2. #SXSW
# &quot;I'm too fond of my iPad.&quot; - @mention #sxswi #SXSW
# #futuremf Trajan: Google has destroyed the &lt;title&gt; tag - websites SEO them. Open Graph Protocol added a clean title tag instead #sxsw
# Attending TV + New Media = Formula for Success at #sxsw. Seeing a lot of iPad 2's around here.
# There are two apple stores in ATX!! RT @mention The iPad 2 goes on sale next Friday...the Austin Apple Store is going to be busy! #SXSWÛ
# Apple has two Austin stores but until this week no downtown presence. That changes with an #sxsw popup store {link} ~@mention
# Do i know u? Why u selling to me! Weve never talked. I now Hate your product! RT @mention check out Heyo 4 iPhone #SXSW #SXSWi
# ÛÏ@mention Unloading at #apple store corner of 6th and congress in Austin. Temp store for #SXSW  {link} / dis awesome!
# Apple Pop Up Store for #SXSW, Why not Pop Up Genius Bars - Everywhere?
# Apple pop up store... line is ridic. #sxsw  {link}
# Trying to update software (4.0) on iPhone to download #sxsw app. But so far no luck - wonder if it's because phone is from Mexico.
# Def could use an iPad for  #SXSW today. Tweeting via iPhone sorta pretty much sux.
# Brilliant use case! #SXSW &quot;@mention ...kik concierge service is great. Get @mention for android or iPhone and add the sxsw user &amp; ask away&quot;
# .@mention used @mention 's @mention iPad app as an example of good navigation! #UXDes #sxsw {link}
# ...
# Great visualisation of the ghost movement logic in PacMan during the Google Doodles session @mention #sxsw. More details here. {link}
# wow you suck {link} iPad #sxsw Rebecca Black #fab5
# Google could = search engines. Google instead = useful information. #savebrands #sxsw
# Google would be a great partner for us, says @mention Looking for more distribution and better products. #sxsw
# Room is full here at re iPad design headaches talk. #sxsw
# Google launches Route Around Traffic - offers 3 options to keep you out of traffic. Saves 2yrs worth of time...every day. #sxsw
# Lines around the block for the new iPad 2 in Austin #sxsw. This is one lucky recipient.  {link}
# Route around traffic from google maps saves users 2 years worth of time...everyday #sxsw
# We're so ungrateful bc we have too much shit to play with. So turn off some of your shit (iPhone) now and then. #sxsw
# Kind of funny/sad that the iPad release line was longer than any party lines (i saw) at #sxsw last night. #sheeple
# Google &quot;ad preferences&quot; and you can view (and edit) what Google thinks you like. #seenocreepy #SXSW
# I picked up a &quot;mophie&quot; iPhone charge case at the #sxsw tradeshow. Doubt I'll use it all the time but it's great for long days out.
# I picked up a white #ipad2 today at the Apple Store, #SXSW!
# Catching up with @mention in our hotel room after day 1 of #sxsw. Also, tweeting this from my new iPad.
# Bad news update: the pop-up Apple Store is out of iPads! Not sure if they will have more by tomorrow. #SXSW
# Another super smart move by apple  {link} Temporary store at SXSW #apple #sxsw
# What's your take on iPad? @mention I really want it! #checkins #sxsw
# What I journal with on my iPhone: RT @mention ** Momento is on SALE for #SXSW ** - Grab it now for just 59p / 99å¢! {link}
# Packed house for Google/Bing Q&amp;A on search rankings. OH: &quot;I'm hope it's a catfight.&quot; #sxsw #qagb
# Over 40% use of google maps is mobile -marissa mayer #sxsw
# Packed house-go Lynn!  Designing iPad Interfaces - New Navigation Schemas at #SXSW #UXDes
# {link}
# @mention used @mention 's @mention iPad app as an example of good navigation! #sxsw {link} via @mentionn
# Someone just held up iPad with giant LIKE on it. Love #SXSW.
# Apple's customer service is top notch. They've even got guys hanging out with the line giving inventory updates and just being nice #sxsw
# Stellar customer service at the #apple store. Wish every purchase was that smooth. :) #sxsw
# Yup #showusyouricrazy RT @mention Apple's pop-up store @mention #SXSW on the day of iPad2 release could b the most genius move in mktg history
# Heading out to the Google/ACLU/EFF party. Yep. Me and Google. Throwing them back. Reliving old times. Should be fun. ##sxsw
# geeking out? RT @mention If you haven't waited in line for an Apple product you're missing out on an important rite of passage. #sxsw
# Google route around traffic saving drivers 2 years of time per day by finding best route. #sxsw
# Google Route-Around Traffic is pretty sweet. Route-Around is saving users 2 years each day! Efficient for time and the environment. #SXSW
# My ipad auto completes Kawasaki's name from the first four letters #sxsw
# Waiting outside the #SXSW Apple store for my #iPad2
# #woohoo
# Ben benieuwd! RT @mention We interrupt your regularly scheduled #sxsw geek programming with big news {link}  #google #circles
# Google dev at the panel indicates that Android now has a Screen Reader that works with widgets, native ui, web views and the browser #SXSW
# @mention V1.2 of #SXSW GO iPhone/iPad app is now live. Better updates &amp; My Schedule sync. Would love to know what you think {link}
# The most valuable device at #sxsw so far is the #apple #iPod #iPhone charger.
# Users drive 12B+ miles a year with Google Maps Navigation ^JR #sxsw
# If you have an iPad DO NOT upgrade to the newest iOS yet, TweetDeck is very unstable on it #nten #11ntc #sxsw #sxswi
# fuck I love Austin. Just left the Youtube Google party at Maggie Maes. Fun times! Got some Youtube Tube Socks. LOL #sxsw #austin
# Genius move by Apple to open a temp. store in downtown Austin for #SXSW: {link} /via @mention #ipad2
# You'll have to wait 4-5 weeks for an iPad 2, but not at the #AppleATXdt pop-up! Shipments daily (via @mention #SXSW
# iPad 2 giveaway in full-force!  Person with most friends in his/her city by end of #SXSW wins! Hint, a strong email list works well! #sxswi
# If you haven't already, download the (free) #SXSW music sampler from iTunes {link} (iTunes link). It's good!
# If you haven't waited in line for an Apple product you're missing out on an important rite of passage.  #sxsw
# Thank heavens for nice travelers. Got a iPhone charger from another delayed @mention passenger. #sxsw
# Bounced over to catch Google's Marissa Mayer speak. Always admired her - intelligent, classy, successful. #girlcrush #sxsw
# heading over with @mention shortly to record some video at the popup apple store at southby - expecting big ipad2 sales! #sxsw
# Totally overshadowing #sxsw. Apple wins again. RT @mention iPad 2 Arrives Tomorrow at 5 p.m.
# Porting everything to my new Ipad2 before I head off to #SxSW on Sunday. Syncing over 3K songs takes a while. #apple
# We are giving away an #iPad at #SXSW for all you mappers out there. Entry is amazingly easy, here are details: {link}
# We are giving away an iPad 2 to kick off our time down at #sxsw. Just visit our FB page for more info: {link}
# Photo: Saving up for an iPad 2 #SXSW style! #HPSXSW (Taken with instagram) {link}
# Rescuing virtual robots in your daily life with your iPhone. Envisioning the day of the last tv broadcast. And that's just the morning #sxsw
# Got the #VMware Talent Community iPad app rockin and signing up talented professionals tonight! Find me! #sxsw {link}
# Auntie's voxpop of  popular #sxsw apps is worth a watch: {link} Not many Android phones on view.
# Loving new @mention for iPhone w #SXSW channel by @mention
# Need a few #android loving volunteers from 10:45am-3 at #sxsw
# I love how #sxsw is an alt universe where everyone uses Apple products and @mention is the fastest way to reach someone
# Don't know 1 user RT @mention Who uses Google TV in this room? Nobody raises a hand in a packed room at the #socialviewing session at #sxsw
# This #sxsw app by #MxM is made of AWESOME! --  {link}   --{link}
# More #SXSW Awesomeness! Apple is opening up a temporary store in downtown Austin for #SXSW and the iPad 2 launch {link}
# Dear #SXSW goer... Please look up from your fucking iPhone when walking the halls. Thanks Hipsters. Hilarious!
# This #SXSW I am grateful for: my bicycle, having a back-up Twitter app. Cursing: losing an hour of zzzs, iPhone battery life.
# Dear #sxsw iPhone app: you suck again this year! (sitby.us is great but doesn't include film sessions)
# Wow, #SXSW is so big that Apple is not just attending, their bringing along a temporary store! {link}
# Free #SXSW music sampler on #itunes. Includes @mention Barton Hollow. (opens itunes) {link}
# I just saw someone filming the #sxsw trade show floor w a teeny hand held steady cam for his iPhone. #jealous
# Free #SXSW streams/downloads via new free Winamp app in Android market, direct link to app download in market {link}
# I love how the Mac:PC ratio is like 25 to 1 and the iPad:Person ratio is like three-quarters to one #sxsw (Seriously. Ton of iPads)
# Apple know their target audience. Pop-up shop @mention SxSW to sell iPad 2 on launch day. #SxSW #Apple
# If there was a popup store in Austin that sold nothing but iPhone battery extenders, it would make so much money. #sxsw
# If there was ever any doubt on the influence of Apple on the innovation community just have a look a #sxsw iPads and iPhone4's EVERYWHERE..
# I wish I was in Austin, if only for the free iPad 2s. #sxsw
# #SXSW crowd in Austin swarms for iPad 2 launch {link} via @mention - sadly I wasn't one of them :-(
# #SXSW crowd in Austin swarms for iPad 2 launch {link} via @mention - sadly I wasn't one of them :-( (via @mention
# #SXSW crowd swarms for #iPad2 launch {link} via @mention #SXSW2011 #apple
# #SXSW crowd swarms for iPad 2 launch  | @mention {link}
# #SXSW crowd swarms for iPad 2 launch - {link} (via @mention
# #SXSW crowd swarms for iPad 2 launch {link} via @mention
# Looking fwd to iPad DJ @mention at our @mention After Dark party tonight. Great first day #SXSW! {link}
# @mention we were on the right track RT @mention clever - Apple set to open popup shop in core of #SXSW action {link}
# @mention We're tight w/ Google. Lot of my friends work there, employees used to work there. We're tight w/ them, tight w/ Twitter. #sxsw
# #SXSW I tweeted too fast it appears Google may do a preview today of Circles their new Social endeavor.
# @mention Well, I hope you make it easier for me to FIND you. I have a little Android who wants to say HI! #sxsw#
# I wish I were at #sxsw. I wish I had an iPad 2. There, I said it.
# Ummmm...awesome? Party? RT djroe Apple store downtown Austin open til Midnight. #sxsw
# @mention What are the chances they'll have a booth selling new iPad 2s? #SXSW
# @mention what did you think of google presentation? Nice to see more retail peeps at #sxsw
# @mention What's going on at #sxsw today? Share photos, video with iReport: {link} or through CNN iPhone app!
# @mention What's the wait time lookin like? The Apple Store up north is already sold out, any word on the #SXSW inventory?
# Debating which laptop to take to #SXSW when I'd rather be taking an iPad 2. #firstworldproblems
# We see a WHITE IPAD 2! RT @mention Now you know what @mention apartment at #sxsw looks like... NEEDS MORE WIRES {link}
# @mention Who said you won't be able to get the iPad 2 at #SXSW?
#
# Apple is opening a pop-up store in Austin for SXSW {link}
# Livetapp will be raffling off an iPad 2 at #SXSW - check-in (and tweet it) at any sxsw show and you'll be entered to win! #music #rewards
# At #SXSW with a thirsty gadget? Using @mention Charge Anywhere for my iPhone, happy to share some juice.
# Jonathan with Zaggle showed us a cool free texting app for iPhone called ZMS @mention #SXSW
# Walkin down the street @mention is navigating via Google, I'm tweeting and random guy is yelping!! Welcome to #SXSW!!
# umm that would be @mention ÛÏ@mention I keep winning shit! Thanks @mention for the killer iPad case. #sxswÛ
# #iPad #news #apps not popular with the #kids. {link} #the_daily is a terrible concept anyway #sxsw
# Apple knows what game they're in at #sxsw. Bring the iPad2 to the people! {link}
# Hmmm...Taxi Magic on iPhone does not appear to be so magic any more in Austin #sxsw
# Great 3D XML visualization of skiers using Google location data. #sxsw
# FestivalExplorer iPhone App Finally Solves SXSW {link} #music #musica #musiek #musique #musik #app #sxsw #Ù_¾¬â #Ù_¾´_ #Î¥É
# Before #sxsw even starts, Apple has captured the attention of the whole show. They win again.  Must have been taking lessons from Sheen. #fb
# iPAD / #SXSW PEOPLE: @mention brilliant Spider: The Secret of Bryce Manor is only 99 cents right now. BUY IT: {link}
# PDX to #sxsw tomorrow. Drop me a note if you'll be there too. #tmsxsw -- Apple pop-up retail store should be the epicenter of the madness.
# I love #sxsw. I opened the @mention app on my iPad at @mention party to settle an argument about parentheses use.  #wordnerd
# Group #Texting War Heats Up: Fast Society Launches New Android App, Updates iPhone App: #SXSWÛ_ {link}
# Our lovely #SXSW iPhone app is UP! get it now!!! Thanks to @mention for the awesome integration! :D {link}
# Started my #sxsw planning last night with the official iPad app...It's a solid resource, but still comes up short for scheduling.
# #tapworthy #winning #tigerblood the tenets of iPad design? #sxsw
# BEST newly added iPhone app goes to @mention awesome!! #SXSW 2011 here I come for one day and one amazing day it will be!!
# Biomimicry as the basis of design and problem solving. Google studying flocking and swarming behavior to understand collab. Brilliant. #sxsw
# Google guy at #sxsw talk is explaining how he made realistic Twitter bots as an experiment. Gee, thanks for doing that.
# Leaving my bag at home today; traveling light with just my iPad in hand. I really don't need to lug around all that impedimenta. #sxsw
# Absolutely beautiful day in Austin for #sxsw. Off to the mall with the guys to track down iPad 2.
# By the way being at #sxsw means I now have to get an iPad or 2
# I think my effing hubby is in line for an #iPad 2. Can someone point him towards the line-up for wife number #2. #sxswi #sxsw
# This is my friend @mention new #iphone #photosharing app he's developed. Ck it out and show your support! {link} #sxsw
# It's crazy how much culture is documented in google doodles. #sxsw
# Ipad's day in the geekest place in the world right now..yes u have a queue: Apple just opens a hidden store {link} #SXSW
# Looks very interesting RT@mention Google to Launch Major New Social Network Called Circles, Possibly Today {link} #sxsw
# Getting my ipad2 #sxsw (@mention Apple Store w/ 4 others) {link}
# Data on my iPhone finally sorted. Next stop: #sxsw!
# Dropped my MacBook pro as I was walking into #sxsw. iPad 2 sounding pretty appealing right now. Somehow I will adapt and overcome.
# Creativity prompt: use Google maps to virtually take a walk you used to take as a kid; see what memories come up. (courtesy @mention #SXSW
# I'm pretty sure the panelist that thinks &quot;Apple is drowning in their success&quot; is fucking insane. #SXSW
# Very happy that Discovr has been named as one of the top ten must-have apps for iPad 2 :) I just have to fight my way thru the queue! #sxsw
# apparently the line to get an iPad at the #sxsw store grew by 2 blocks to 5 blocks in the past 30 mins. WUT.
# Apparently there is an iPad and iPhone app to block #sxsw tweets. :)
# On the way to #sxsw, see you all tonight! hopefully with a new ipad ;) (@mention San Francisco International Airport (SFO)) {link}
# By the way, I love that y'all are so down to discuss apple-breeds in the midst of all of this pre-#sxsw madness!
# Absolutely!  RT @mention Timely good schtuff from Google (People Finder 4 japan quake) {link} #iQlab #sxsw
# Good job y'all!  RT @mention Yes! Gowalla wins best Andoid app at the Team Android Choice Awards. Thanks all! #sxsw
# [TOP STORY] At #SXSW, Apple schools the marketing experts: Thousands in town to demonstrate their social mar... {link} #sxswi
# @mention yep! I can't believe they set up a pop up store. Oh wait, yes I can :) #sxsw #apple
# @mention Yes, that's why I favorited it! I want to win. I need to win. doo dah doo dah. :D #pushio #sxsw #ipad
# Hey is anyone doing #sxsw signing up for the group texting app, groupme? got it on my iphone, but no one else is on it, so....kinda useless.
# Look everyone! Zomg @mention got an iPad 2 on the first day! #sxsw {link}
# @mention you are my favorite-- thanks for coming to @mention -- when you getting an iPhone again?? #SXSW
# @mention you can buy my used iPad and I'll pick one up tomorrow ;-) #sxsw
# @mention You could buy a new iPad 2 tmrw at the Apple pop-up store at #sxsw: {link}
# @mention you might also appreciate new iPhone app tweetcaster. Zip it feature let's you hide ANY keywords or hashtag, incl of course #sxsw :)
# @mention You realize I'm still padless? I just gave away a case at #bmm with @mention - need to win the next iPad first. #sxsw
# You know you've made it to #sxsw when you see a bunch of grown men hooting over getting the iPad 2
# what are your essentials for #SxSW?  Mine? pocket camera, laptop, iPad, extra cords...
# @mention your iPhone 4 cases are Rad and Ready! Stop by tomorrow to get them! #Sxsw #zazzlesxsw #sxswi {link}
# @mention your PR guy just convinced me to switch back to iPhone. Great #sxsw coverage. #princess
# Diller says Google TV &quot;might be run over by the PlayStation and the Xbox, which are essentially ready today.&quot; #sxsw #diller
# I've always used Camera+ for my iPhone b/c it has an image stabilizer mode. Suggestions for an iPad cam app w/ same feature? #SXSW #SXSWi
# Ipad everywhere. #SXSW {link}

# %% [markdown]
# ## Multiclass Classification

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# # iNTERPRET

# %% [markdown]
# Evaluate how well your work solves the stated business problem.
#
# ***
# Questions to consider:
# * How do you interpret the results?
# * How well does your model fit your data? How much better is this than your baseline model?
# * How confident are you that your results would generalize beyond the data you have?
# * How confident are you that this model would benefit the business if put into use?
# ***

# %% [markdown]
# # CONCLUSIONS & RECOMMENDATIONS

# %% [markdown]
# Provide your conclusions about the work you've done, including any limitations or next steps.
#
# ***
# Questions to consider:
# * What would you recommend the business do as a result of this work?
# * What are some reasons why your analysis might not fully solve the business problem?
# * What else could you do in the future to improve this project?
# ***
